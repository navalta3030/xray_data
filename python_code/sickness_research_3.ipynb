# %%
# !pip uninstall tensorflow -y
# !pip install tensorflow==2.1

# %%
# Run this one if using google colab
from google.colab import drive
import sys
import os

drive.mount('/content/gdrive', True)
sys.path.append("/content/xray_code/python_code")

if not os.path.exists("/content/xray_code"):
  # !cp -r "/content/gdrive/My Drive/xray_code/" "/content/xray_code"
# Out:
# Mounted at /content/gdrive

# %%
# %load_ext autoreload
# %autoreload 2

from utils import *
from ml_utils import XrayTF
from tqdm import tqdm_notebook as tqdm
from threading import Thread
from constants import LOCAL_IMAGES_LOCATION

import urllib.request as req
import matplotlib.pyplot as plt
import numpy as np
import time
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Load csv if exist, if not get the original one and parse it

# %%
"""
SICKNESS = "Infiltration"
SICKNESS = "Pneumonia"
SICKNESS = "Mass"
SICKNESS = "Pneumothorax"
"""

SICKNESS = "Pneumonia"
csv_file = "new_normalized_xray_without_full_path.csv"
csv_file_full_path = f'/content/gdrive/My Drive/xray_code/sheet/{csv_file}'

IMAGE_SIZE = 224
BATCH_SIZE = 32
EPOCH = 1000

pd.set_option('display.max_colwidth', -1)


# take existing if it exist
if os.path.exists(csv_file_full_path):
    df = pd.read_csv(csv_file_full_path)
    xray_class = XrayTF(df, IMAGE_SIZE, BATCH_SIZE)
    xray_class.prepend_image_full_path()
else:
    df = get_data_sheet()
    df = normalize_data_frame(df)
    xray_class = XrayTF(df, IMAGE_SIZE, BATCH_SIZE)
    xray_class.prepend_image_full_path()
    xray_class.df.to_csv(csv_file_full_path, index=False)

xray_class.df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   app.launch_new_instance()
#    Unnamed: 0        Image Index  ... x_pixel_spacing y_pixel_spacing
# 0  0           IM-0001-0001.jpeg  ... NaN             NaN
# 1  1           IM-0003-0001.jpeg  ... NaN             NaN
# 2  2           IM-0005-0001.jpeg  ... NaN             NaN
# 3  3           IM-0006-0001.jpeg  ... NaN             NaN
# 4  4           IM-0007-0001.jpeg  ... NaN             NaN
#
# [5 rows x 12 columns]

# %% [markdown]
# # Analyze our data set
# - take a look at the distribution
# - prepare data before splitting to test and train
#   - Get image based on xray Position
#   - Select a sickness and balance them
# - Generate Age histogram

# %%
print(xray_class.df["View Position"].value_counts())
print("="*50)
print(xray_class.df.labels.value_counts())
# Out:
# PA    87486
# AP    59907
# Name: View Position, dtype: int64
# ==================================================
# No Finding            60361
# Infiltration          19894
# Effusion              13317
# Atelectasis           11559
# Nodule                6331
# Mass                  5782
# Pneumonia             5704
# Pneumothorax          5302
# Consolidation         4667
# Pleural_Thickening    3385
# Cardiomegaly          2776
# Emphysema             2516
# Edema                 2303
# Fibrosis              1686
# No Fiding             1583
# Hernia                227
# Name: labels, dtype: int64

# %%
# Pick a sickness
xray_class.use_one_label(SICKNESS, balance=True)

# Verify how balanced our data is
print(xray_class.df.labels.value_counts())
print(xray_class.df["Patient Gender"].value_counts())
# Out:
# Pneumonia     5704
# No Finding    5704
# Name: labels, dtype: int64
# M    4028
# F    3107
# Name: Patient Gender, dtype: int64

# %%
xray_class.df["Patient Age"].hist(bins=30).set_xlim(0,100)
# Out:
# (0.0, 100.0)

# %% [markdown]
# # Download our data
# - Parallel download from digital ocean
# - prepend system path after download

# %%
# !rm -rf /content/images
if not os.path.exists(LOCAL_IMAGES_LOCATION):
  # !mkdir /content/images

  class Downloader(Thread):
    def __init__(self, file_url, save_path):
        Thread.__init__(self)
        self.file_url = file_url
        self.save_path = save_path

    def run(self):
        remaining_download_tries = 15

        while remaining_download_tries > 0:
            try:
                req.urlretrieve(self.file_url, self.save_path)
                time.sleep(0.1)
            except:
                print("error downloading " + self.file_url +
                      " on trial no: " + str(16 - remaining_download_tries))
                remaining_download_tries = remaining_download_tries - 1
                continue
            else:
                break

  xray_class.df["Image Index"].apply(lambda x: Downloader(x, LOCAL_IMAGES_LOCATION + x.split('/')[-1] ).start() )
# Out:
# Streaming output truncated to the last 5000 lines.
# error downloading 00001182_009.png on trial no: 12
# error downloading 00001182_009.png on trial no: 13
# error downloading 00001182_009.png on trial no: 14
# error downloading 00001182_009.png on trial no: 15
# error downloading 00005057_000.png on trial no: 1
# error downloading 00005057_000.png on trial no: 2
# error downloading 00005057_000.png on trial no: 3
# error downloading 00005057_000.png on trial no: 4
# error downloading 00005057_000.png on trial no: 5
# error downloading 00005057_000.png on trial no: 6
# error downloading 00005057_000.png on trial no: 7
# error downloading 00005057_000.png on trial no: 8
# error downloading 00005057_000.png on trial no: 9
# error downloading 00005057_000.png on trial no: 10
# error downloading 00005057_000.png on trial no: 11
# error downloading 00005057_000.png on trial no: 12
# error downloading 00005057_000.png on trial no: 13
# error downloading 00005057_000.png on trial no: 14
# error downloading 00005057_000.png on trial no: 15
#
# error downloading 00014911_002.png on trial no: 2
# error downloading 00014911_002.png on trial no: 3
# error downloading 00017087_000.png on trial no: 2error downloading 00007202_000.png on trial no: 1
# error downloading 00007202_000.png on trial no: 2
# error downloading 00009684_000.png on trial no: 1
#
# error downloading 00009684_000.png on trial no: 2
# error downloading 00009684_000.png on trial no: 3
# error downloading 00009684_000.png on trial no: 4
# error downloading 00009684_000.png on trial no: 5
# error downloading 00009684_000.png on trial no: 6
# error downloading 00009684_000.png on trial no: 7
# error downloading 00009684_000.png on trial no: 8
# error downloading 00009684_000.png on trial no: 9
# error downloading 00009684_000.png on trial no: 10
# error downloading 00009684_000.png on trial no: 11
# error downloading 00009684_000.png on trial no: 12
# error downloading 00009684_000.png on trial no: 13
# error downloading 00009684_000.png on trial no: 14
# error downloading 00009684_000.png on trial no: 15
# error downloading 00017087_000.png on trial no: 3
# error downloading 00017087_000.png on trial no: 4
# error downloading 00017087_000.png on trial no: 5
# error downloading 00017087_000.png on trial no: 6
# error downloading 00017087_000.png on trial no: 7
# error downloading 00017087_000.png on trial no: 8
# error downloading 00017087_000.png on trial no: 9
# error downloading 00017087_000.png on trial no: 10
# error downloading 00017087_000.png on trial no: 11
# error downloading 00017087_000.png on trial no: 12
# error downloading 00017087_000.png on trial no: 13
# error downloading 00017087_000.png on trial no: 14
# error downloading 00017087_000.png on trial no: 15
# error downloading 00019038_003.png on trial no: 1error downloading 00014911_002.png on trial no: 4error downloading 00011579_046.png on trial no: 1
# error downloading 00011579_046.png on trial no: 2
# error downloading 00011579_046.png on trial no: 3
# error downloading 00011579_046.png on trial no: 4
# error downloading 00011579_046.png on trial no: 5
# error downloading 00011579_046.png on trial no: 6
# error downloading 00011579_046.png on trial no: 7
# error downloading 00011579_046.png on trial no: 8
# error downloading 00011579_046.png on trial no: 9
# error downloading 00011579_046.png on trial no: 10
# error downloading 00011579_046.png on trial no: 11
# error downloading 00011579_046.png on trial no: 12
# error downloading 00011579_046.png on trial no: 13
# error downloading 00011579_046.png on trial no: 14
# error downloading 00011579_046.png on trial no: 15
#
# error downloading 00007202_000.png on trial no: 3
# error downloading 00007202_000.png on trial no: 4
# error downloading 00007202_000.png on trial no: 5
# error downloading 00007202_000.png on trial no: 6
# error downloading 00007202_000.png on trial no: 7
# error downloading 00007202_000.png on trial no: 8
# error downloading 00007202_000.png on trial no: 9
# error downloading 00007202_000.png on trial no: 10
# error downloading 00007202_000.png on trial no: 11
# error downloading 00007202_000.png on trial no: 12
# error downloading 00007202_000.png on trial no: 13
# error downloading 00007202_000.png on trial no: 14
# error downloading 00007202_000.png on trial no: 15
# error downloading 00021489_002.png on trial no: 1
# error downloading 00021489_002.png on trial no: 2
# error downloading 00014911_002.png on trial no: 5
# error downloading 00014911_002.png on trial no: 6
# error downloading 00014911_002.png on trial no: 7
# error downloading 00014911_002.png on trial no: 8
# error downloading 00014911_002.png on trial no: 9
# error downloading 00014911_002.png on trial no: 10
# error downloading 00014911_002.png on trial no: 11
# error downloading 00014911_002.png on trial no: 12
# error downloading 00014911_002.png on trial no: 13
# error downloading 00014911_002.png on trial no: 14
# error downloading 00014911_002.png on trial no: 15
#
# error downloading 00021489_002.png on trial no: 3
#
# error downloading 00021489_002.png on trial no: 4error downloading 00003038_001.png on trial no: 1
# error downloading 00021489_002.png on trial no: 5
# error downloading 00021489_002.png on trial no: 6
# error downloading 00021489_002.png on trial no: 7
# error downloading 00021489_002.png on trial no: 8
# error downloading 00021489_002.png on trial no: 9
# error downloading 00021489_002.png on trial no: 10
# error downloading 00021489_002.png on trial no: 11
# error downloading 00021489_002.png on trial no: 12
# error downloading 00021489_002.png on trial no: 13
# error downloading 00021489_002.png on trial no: 14
# error downloading 00021489_002.png on trial no: 15
# error downloading 00019038_003.png on trial no: 2
# error downloading 00019038_003.png on trial no: 3
# error downloading 00019038_003.png on trial no: 4
# error downloading 00019038_003.png on trial no: 5
# error downloading 00019038_003.png on trial no: 6
# error downloading 00019038_003.png on trial no: 7
# error downloading 00019038_003.png on trial no: 8
# error downloading 00019038_003.png on trial no: 9
# error downloading 00019038_003.png on trial no: 10
# error downloading 00019038_003.png on trial no: 11
# error downloading 00019038_003.png on trial no: 12error downloading 00004418_008.png on trial no: 1
# error downloading 00004418_008.png on trial no: 2
# error downloading 00004418_008.png on trial no: 3
# error downloading 00004418_008.png on trial no: 4
# error downloading 00004418_008.png on trial no: 5
# error downloading 00004418_008.png on trial no: 6
# error downloading 00004418_008.png on trial no: 7
# error downloading 00004418_008.png on trial no: 8
# error downloading 00004418_008.png on trial no: 9
# error downloading 00004418_008.png on trial no: 10
# error downloading 00004418_008.png on trial no: 11
# error downloading 00004418_008.png on trial no: 12
# error downloading 00004418_008.png on trial no: 13
# error downloading 00004418_008.png on trial no: 14
# error downloading 00004418_008.png on trial no: 15
#
# error downloading 00019038_003.png on trial no: 13
# error downloading 00019038_003.png on trial no: 14
# error downloading 00019038_003.png on trial no: 15
#
# error downloading 00029490_001.png on trial no: 1
# error downloading 00029490_001.png on trial no: 2error downloading 00005771_000.png on trial no: 1error downloading 00003038_001.png on trial no: 2
# error downloading 00003038_001.png on trial no: 3
# error downloading 00003038_001.png on trial no: 4
# error downloading 00003038_001.png on trial no: 5
# error downloading 00003038_001.png on trial no: 6
# error downloading 00003038_001.png on trial no: 7
# error downloading 00003038_001.png on trial no: 8
# error downloading 00003038_001.png on trial no: 9
# error downloading 00003038_001.png on trial no: 10
# error downloading 00003038_001.png on trial no: 11
# error downloading 00003038_001.png on trial no: 12
# error downloading 00003038_001.png on trial no: 13
# error downloading 00003038_001.png on trial no: 14
# error downloading 00003038_001.png on trial no: 15
# error downloading 00003657_000.png on trial no: 1
# error downloading 00003657_000.png on trial no: 2
# error downloading 00003657_000.png on trial no: 3
# error downloading 00003657_000.png on trial no: 4
# error downloading 00003657_000.png on trial no: 5
# error downloading 00003657_000.png on trial no: 6
# error downloading 00003657_000.png on trial no: 7
# error downloading 00003657_000.png on trial no: 8
# error downloading 00003657_000.png on trial no: 9
# error downloading 00003657_000.png on trial no: 10
# error downloading 00003657_000.png on trial no: 11
# error downloading 00003657_000.png on trial no: 12
# error downloading 00003657_000.png on trial no: 13
# error downloading 00003657_000.png on trial no: 14
# error downloading 00003657_000.png on trial no: 15
#
#
# error downloading 00029490_001.png on trial no: 3
# error downloading 00029490_001.png on trial no: 4
# error downloading 00029490_001.png on trial no: 5
# error downloading 00029490_001.png on trial no: 6
# error downloading 00029490_001.png on trial no: 7
# error downloading 00029490_001.png on trial no: 8
# error downloading 00029490_001.png on trial no: 9
# error downloading 00029490_001.png on trial no: 10
# error downloading 00029490_001.png on trial no: 11
# error downloading 00029490_001.png on trial no: 12
# error downloading 00029490_001.png on trial no: 13
# error downloading 00029490_001.png on trial no: 14
# error downloading 00029490_001.png on trial no: 15
# error downloading 00005771_000.png on trial no: 2
# error downloading 00005771_000.png on trial no: 3
# error downloading 00005771_000.png on trial no: 4
# error downloading 00005771_000.png on trial no: 5
# error downloading 00005771_000.png on trial no: 6
# error downloading 00005771_000.png on trial no: 7
# error downloading 00005771_000.png on trial no: 8
# error downloading 00005771_000.png on trial no: 9
# error downloading 00005771_000.png on trial no: 10
# error downloading 00005771_000.png on trial no: 11
# error downloading 00005771_000.png on trial no: 12
# error downloading 00005771_000.png on trial no: 13
# error downloading 00005771_000.png on trial no: 14
# error downloading 00005771_000.png on trial no: 15
# error downloading 00007885_004.png on trial no: 1
# error downloading 00007885_004.png on trial no: 2
# error downloading 00007885_004.png on trial no: 3
# error downloading 00007885_004.png on trial no: 4
# error downloading 00007885_004.png on trial no: 5
# error downloading 00007885_004.png on trial no: 6
# error downloading 00007885_004.png on trial no: 7
# error downloading 00007885_004.png on trial no: 8
# error downloading 00007885_004.png on trial no: 9
# error downloading 00007885_004.png on trial no: 10
# error downloading 00007885_004.png on trial no: 11
# error downloading 00007885_004.png on trial no: 12
# error downloading 00007885_004.png on trial no: 13
# error downloading 00007885_004.png on trial no: 14
# error downloading 00007885_004.png on trial no: 15
# error downloading 00011963_006.png on trial no: 1
# error downloading 00011963_006.png on trial no: 2
# error downloading 00011963_006.png on trial no: 3
# error downloading 00011963_006.png on trial no: 4
# error downloading 00011963_006.png on trial no: 5
# error downloading 00011963_006.png on trial no: 6
# error downloading 00011963_006.png on trial no: 7
# error downloading 00011963_006.png on trial no: 8
# error downloading 00011963_006.png on trial no: 9
# error downloading 00011963_006.png on trial no: 10
# error downloading 00011963_006.png on trial no: 11
# error downloading 00011963_006.png on trial no: 12
# error downloading 00011963_006.png on trial no: 13
# error downloading 00011963_006.png on trial no: 14
# error downloading 00011963_006.png on trial no: 15
# error downloading 00011645_000.png on trial no: 1
# error downloading 00011645_000.png on trial no: 2
# error downloading 00011645_000.png on trial no: 3
# error downloading 00011645_000.png on trial no: 4
# error downloading 00011645_000.png on trial no: 5
# error downloading 00011645_000.png on trial no: 6
# error downloading 00011645_000.png on trial no: 7
# error downloading 00011645_000.png on trial no: 8
# error downloading 00011645_000.png on trial no: 9
# error downloading 00011645_000.png on trial no: 10
# error downloading 00011645_000.png on trial no: 11
# error downloading 00011645_000.png on trial no: 12
# error downloading 00011645_000.png on trial no: 13
# error downloading 00011645_000.png on trial no: 14
# error downloading 00011645_000.png on trial no: 15
# error downloading 00010043_000.png on trial no: 1
# error downloading 00010043_000.png on trial no: 2
# error downloading 00010043_000.png on trial no: 3
# error downloading 00010043_000.png on trial no: 4
# error downloading 00010043_000.png on trial no: 5
# error downloading 00010043_000.png on trial no: 6
# error downloading 00010043_000.png on trial no: 7
# error downloading 00010043_000.png on trial no: 8
# error downloading 00010043_000.png on trial no: 9
# error downloading 00010043_000.png on trial no: 10
# error downloading 00010043_000.png on trial no: 11
# error downloading 00010043_000.png on trial no: 12
# error downloading 00010043_000.png on trial no: 13
# error downloading 00010043_000.png on trial no: 14
# error downloading 00010043_000.png on trial no: 15
# error downloading 00010198_012.png on trial no: 1
# error downloading 00010198_012.png on trial no: 2
# error downloading 00010198_012.png on trial no: 3
# error downloading 00010198_012.png on trial no: 4
# error downloading 00010198_012.png on trial no: 5
# error downloading 00010198_012.png on trial no: 6
# error downloading 00010198_012.png on trial no: 7
# error downloading 00010198_012.png on trial no: 8
# error downloading 00010198_012.png on trial no: 9
# error downloading 00010198_012.png on trial no: 10
# error downloading 00010198_012.png on trial no: 11
# error downloading 00010198_012.png on trial no: 12
# error downloading 00010198_012.png on trial no: 13
# error downloading 00010198_012.png on trial no: 14
# error downloading 00010198_012.png on trial no: 15
# error downloading 00004556_000.png on trial no: 1error downloading 00020290_002.png on trial no: 1
# error downloading 00020290_002.png on trial no: 2
# error downloading 00020290_002.png on trial no: 3
# error downloading 00020290_002.png on trial no: 4
# error downloading 00005218_000.png on trial no: 1
# error downloading 00005218_000.png on trial no: 2
# error downloading 00005218_000.png on trial no: 3
# error downloading 00005218_000.png on trial no: 4
# error downloading 00005218_000.png on trial no: 5
# error downloading 00005218_000.png on trial no: 6
# error downloading 00005218_000.png on trial no: 7
# error downloading 00005218_000.png on trial no: 8
# error downloading 00005218_000.png on trial no: 9
# error downloading 00005218_000.png on trial no: 10
# error downloading 00005218_000.png on trial no: 11
# error downloading 00005218_000.png on trial no: 12
# error downloading 00005218_000.png on trial no: 13
# error downloading 00005218_000.png on trial no: 14
# error downloading 00020290_002.png on trial no: 5error downloading 00005218_000.png on trial no: 15
# error downloading 00004556_000.png on trial no: 2
# error downloading 00004556_000.png on trial no: 3
# error downloading 00004556_000.png on trial no: 4
# error downloading 00004556_000.png on trial no: 5
# error downloading 00004556_000.png on trial no: 6
# error downloading 00004556_000.png on trial no: 7
# error downloading 00004556_000.png on trial no: 8
# error downloading 00004556_000.png on trial no: 9
# error downloading 00004556_000.png on trial no: 10
# error downloading 00004556_000.png on trial no: 11
# error downloading 00004556_000.png on trial no: 12
# error downloading 00004556_000.png on trial no: 13
# error downloading 00004556_000.png on trial no: 14
# error downloading 00004556_000.png on trial no: 15
#
# error downloading 00013256_002.png on trial no: 1
# error downloading 00013256_002.png on trial no: 2
# error downloading 00013256_002.png on trial no: 3
# error downloading 00013256_002.png on trial no: 4
# error downloading 00013256_002.png on trial no: 5
# error downloading 00013256_002.png on trial no: 6
# error downloading 00013256_002.png on trial no: 7
# error downloading 00013256_002.png on trial no: 8
# error downloading 00013256_002.png on trial no: 9
# error downloading 00013256_002.png on trial no: 10
# error downloading 00020290_002.png on trial no: 6
# error downloading 00020290_002.png on trial no: 7
# error downloading 00020290_002.png on trial no: 8
# error downloading 00020290_002.png on trial no: 9
# error downloading 00020290_002.png on trial no: 10
# error downloading 00020290_002.png on trial no: 11
# error downloading 00020290_002.png on trial no: 12
# error downloading 00020290_002.png on trial no: 13
# error downloading 00020290_002.png on trial no: 14
# error downloading 00020290_002.png on trial no: 15
#
# error downloading 00013256_002.png on trial no: 11
# error downloading 00013256_002.png on trial no: 12
# error downloading 00013256_002.png on trial no: 13
# error downloading 00013256_002.png on trial no: 14
# error downloading 00013256_002.png on trial no: 15
# error downloading 00023826_000.png on trial no: 1
# error downloading 00023826_000.png on trial no: 2
# error downloading 00023826_000.png on trial no: 3
# error downloading 00023826_000.png on trial no: 4
# error downloading 00023826_000.png on trial no: 5
# error downloading 00023826_000.png on trial no: 6
# error downloading 00023826_000.png on trial no: 7
# error downloading 00023826_000.png on trial no: 8
# error downloading 00023826_000.png on trial no: 9
# error downloading 00023826_000.png on trial no: 10
# error downloading 00023826_000.png on trial no: 11
# error downloading 00023826_000.png on trial no: 12
# error downloading 00023826_000.png on trial no: 13
# error downloading 00023826_000.png on trial no: 14
# error downloading 00023826_000.png on trial no: 15
# error downloading 00001568_006.png on trial no: 1error downloading 00005220_005.png on trial no: 1
# error downloading 00005220_005.png on trial no: 2
# error downloading 00005220_005.png on trial no: 3
# error downloading 00005220_005.png on trial no: 4
# error downloading 00005220_005.png on trial no: 5
# error downloading 00005220_005.png on trial no: 6
# error downloading 00005220_005.png on trial no: 7
# error downloading 00005220_005.png on trial no: 8
# error downloading 00005220_005.png on trial no: 9
# error downloading 00005220_005.png on trial no: 10
# error downloading 00005220_005.png on trial no: 11
# error downloading 00005220_005.png on trial no: 12
# error downloading 00005220_005.png on trial no: 13
# error downloading 00005220_005.png on trial no: 14
# error downloading 00005220_005.png on trial no: 15
#
# error downloading 00001568_006.png on trial no: 2
# error downloading 00001568_006.png on trial no: 3
# error downloading 00001568_006.png on trial no: 4
# error downloading 00001568_006.png on trial no: 5
# error downloading 00001568_006.png on trial no: 6
# error downloading 00001568_006.png on trial no: 7
# error downloading 00001568_006.png on trial no: 8
# error downloading 00001568_006.png on trial no: 9
# error downloading 00001568_006.png on trial no: 10
# error downloading 00001568_006.png on trial no: 11
# error downloading 00001568_006.png on trial no: 12
# error downloading 00001568_006.png on trial no: 13
# error downloading 00001568_006.png on trial no: 14
# error downloading 00001568_006.png on trial no: 15
# error downloading 00014470_001.png on trial no: 1
# error downloading 00014470_001.png on trial no: 2
# error downloading 00014470_001.png on trial no: 3
# error downloading 00014470_001.png on trial no: 4
# error downloading 00014470_001.png on trial no: 5
# error downloading 00014470_001.png on trial no: 6
# error downloading 00014470_001.png on trial no: 7
# error downloading 00014470_001.png on trial no: 8
# error downloading 00014470_001.png on trial no: 9
# error downloading 00014470_001.png on trial no: 10
# error downloading 00014470_001.png on trial no: 11
# error downloading 00014470_001.png on trial no: 12
# error downloading 00014470_001.png on trial no: 13
# error downloading 00014470_001.png on trial no: 14
# error downloading 00014470_001.png on trial no: 15
# error downloading 00007762_004.png on trial no: 1
# error downloading 00007762_004.png on trial no: 2
# error downloading 00008043_006.png on trial no: 1
# error downloading 00008043_006.png on trial no: 2
# error downloading 00008043_006.png on trial no: 3
# error downloading 00008043_006.png on trial no: 4
# error downloading 00008043_006.png on trial no: 5
# error downloading 00008043_006.png on trial no: 6
# error downloading 00008043_006.png on trial no: 7
# error downloading 00008043_006.png on trial no: 8
# error downloading 00008043_006.png on trial no: 9
# error downloading 00008043_006.png on trial no: 10
# error downloading 00008043_006.png on trial no: 11
# error downloading 00008043_006.png on trial no: 12
# error downloading 00008043_006.png on trial no: 13
# error downloading 00008043_006.png on trial no: 14
# error downloading 00008043_006.png on trial no: 15
# error downloading 00007762_004.png on trial no: 3
# error downloading 00007762_004.png on trial no: 4
# error downloading 00007762_004.png on trial no: 5
# error downloading 00007762_004.png on trial no: 6
# error downloading 00007762_004.png on trial no: 7
# error downloading 00007762_004.png on trial no: 8
# error downloading 00007762_004.png on trial no: 9
# error downloading 00007762_004.png on trial no: 10
# error downloading 00007762_004.png on trial no: 11
# error downloading 00007762_004.png on trial no: 12
# error downloading 00007762_004.png on trial no: 13
# error downloading 00007762_004.png on trial no: 14
# error downloading 00007762_004.png on trial no: 15
# error downloading 00028099_000.png on trial no: 1
# error downloading 00028099_000.png on trial no: 2
# error downloading 00028099_000.png on trial no: 3
# error downloading 00028099_000.png on trial no: 4
# error downloading 00028099_000.png on trial no: 5
# error downloading 00028099_000.png on trial no: 6
# error downloading 00028099_000.png on trial no: 7
# error downloading 00028099_000.png on trial no: 8
# error downloading 00028099_000.png on trial no: 9
# error downloading 00028099_000.png on trial no: 10
# error downloading 00028099_000.png on trial no: 11
# error downloading 00028099_000.png on trial no: 12
# error downloading 00028099_000.png on trial no: 13
# error downloading 00028099_000.png on trial no: 14
# error downloading 00028099_000.png on trial no: 15
# error downloading 00008897_000.png on trial no: 1
# error downloading 00008897_000.png on trial no: 2
# error downloading 00008897_000.png on trial no: 3
# error downloading 00008897_000.png on trial no: 4
# error downloading 00008897_000.png on trial no: 5
# error downloading 00008897_000.png on trial no: 6
# error downloading 00008897_000.png on trial no: 7
# error downloading 00008897_000.png on trial no: 8
# error downloading 00008897_000.png on trial no: 9
# error downloading 00008897_000.png on trial no: 10
# error downloading 00008897_000.png on trial no: 11
# error downloading 00008897_000.png on trial no: 12
# error downloading 00008897_000.png on trial no: 13
# error downloading 00008897_000.png on trial no: 14
# error downloading 00008897_000.png on trial no: 15
# error downloading 00006585_008.png on trial no: 1
# error downloading 00006585_008.png on trial no: 2
# error downloading 00006585_008.png on trial no: 3
# error downloading 00006585_008.png on trial no: 4
# error downloading 00006585_008.png on trial no: 5
# error downloading 00006585_008.png on trial no: 6
# error downloading 00006585_008.png on trial no: 7
# error downloading 00006585_008.png on trial no: 8
# error downloading 00006585_008.png on trial no: 9
# error downloading 00006585_008.png on trial no: 10
# error downloading 00006585_008.png on trial no: 11
# error downloading 00006585_008.png on trial no: 12
# error downloading 00006585_008.png on trial no: 13
# error downloading 00006585_008.png on trial no: 14
# error downloading 00006585_008.png on trial no: 15
# error downloading 00026002_000.png on trial no: 1
# error downloading 00026002_000.png on trial no: 2
# error downloading 00026002_000.png on trial no: 3
# error downloading 00026002_000.png on trial no: 4
# error downloading 00026002_000.png on trial no: 5
# error downloading 00026002_000.png on trial no: 6
# error downloading 00026002_000.png on trial no: 7
# error downloading 00026002_000.png on trial no: 8
# error downloading 00026002_000.png on trial no: 9
# error downloading 00026002_000.png on trial no: 10
# error downloading 00026002_000.png on trial no: 11
# error downloading 00026002_000.png on trial no: 12
# error downloading 00026002_000.png on trial no: 13
# error downloading 00026002_000.png on trial no: 14
# error downloading 00026002_000.png on trial no: 15
# error downloading 00012681_018.png on trial no: 1
# error downloading 00012681_018.png on trial no: 2
# error downloading 00012681_018.png on trial no: 3
# error downloading 00012681_018.png on trial no: 4
# error downloading 00012681_018.png on trial no: 5
# error downloading 00012681_018.png on trial no: 6
# error downloading 00012681_018.png on trial no: 7
# error downloading 00012681_018.png on trial no: 8
# error downloading 00012681_018.png on trial no: 9
# error downloading 00012681_018.png on trial no: 10
# error downloading 00012681_018.png on trial no: 11
# error downloading 00012681_018.png on trial no: 12
# error downloading 00012681_018.png on trial no: 13
# error downloading 00012681_018.png on trial no: 14
# error downloading 00012681_018.png on trial no: 15
# error downloading 00019842_000.png on trial no: 1
# error downloading 00019842_000.png on trial no: 2
# error downloading 00019842_000.png on trial no: 3
# error downloading 00019842_000.png on trial no: 4
# error downloading 00019842_000.png on trial no: 5
# error downloading 00019842_000.png on trial no: 6
# error downloading 00019842_000.png on trial no: 7
# error downloading 00019842_000.png on trial no: 8
# error downloading 00019842_000.png on trial no: 9
# error downloading 00019842_000.png on trial no: 10
# error downloading 00019842_000.png on trial no: 11
# error downloading 00019842_000.png on trial no: 12
# error downloading 00019842_000.png on trial no: 13
# error downloading 00019842_000.png on trial no: 14
# error downloading 00019842_000.png on trial no: 15
# error downloading 00004999_003.png on trial no: 1
# error downloading 00004999_003.png on trial no: 2
# error downloading 00004999_003.png on trial no: 3
# error downloading 00004999_003.png on trial no: 4
# error downloading 00004999_003.png on trial no: 5
# error downloading 00004999_003.png on trial no: 6
# error downloading 00004999_003.png on trial no: 7
# error downloading 00004999_003.png on trial no: 8
# error downloading 00004999_003.png on trial no: 9
# error downloading 00004999_003.png on trial no: 10
# error downloading 00004999_003.png on trial no: 11
# error downloading 00004999_003.png on trial no: 12
# error downloading 00004999_003.png on trial no: 13
# error downloading 00004999_003.png on trial no: 14
# error downloading 00004999_003.png on trial no: 15
# error downloading 00016103_006.png on trial no: 1
# error downloading 00016103_006.png on trial no: 2
# error downloading 00016103_006.png on trial no: 3
# error downloading 00016103_006.png on trial no: 4
# error downloading 00016103_006.png on trial no: 5
# error downloading 00016103_006.png on trial no: 6
# error downloading 00016103_006.png on trial no: 7
# error downloading 00016103_006.png on trial no: 8
# error downloading 00016103_006.png on trial no: 9
# error downloading 00016103_006.png on trial no: 10
# error downloading 00016103_006.png on trial no: 11
# error downloading 00016103_006.png on trial no: 12
# error downloading 00016103_006.png on trial no: 13
# error downloading 00016103_006.png on trial no: 14
# error downloading 00016103_006.png on trial no: 15
# error downloading 00022332_000.png on trial no: 1
# error downloading 00022332_000.png on trial no: 2
# error downloading 00022332_000.png on trial no: 3
# error downloading 00022332_000.png on trial no: 4
# error downloading 00022332_000.png on trial no: 5
# error downloading 00022332_000.png on trial no: 6
# error downloading 00022332_000.png on trial no: 7
# error downloading 00022332_000.png on trial no: 8
# error downloading 00022332_000.png on trial no: 9
# error downloading 00022332_000.png on trial no: 10
# error downloading 00022332_000.png on trial no: 11
# error downloading 00022332_000.png on trial no: 12
# error downloading 00022332_000.png on trial no: 13
# error downloading 00022332_000.png on trial no: 14
# error downloading 00022332_000.png on trial no: 15
# error downloading 00008489_004.png on trial no: 1
# error downloading 00008489_004.png on trial no: 2
# error downloading 00008489_004.png on trial no: 3
# error downloading 00008489_004.png on trial no: 4
# error downloading 00008489_004.png on trial no: 5
# error downloading 00008489_004.png on trial no: 6
# error downloading 00008489_004.png on trial no: 7
# error downloading 00008489_004.png on trial no: 8
# error downloading 00008489_004.png on trial no: 9
# error downloading 00008489_004.png on trial no: 10
# error downloading 00008489_004.png on trial no: 11
# error downloading 00008489_004.png on trial no: 12
# error downloading 00008489_004.png on trial no: 13
# error downloading 00008489_004.png on trial no: 14
# error downloading 00008489_004.png on trial no: 15
# error downloading 00019067_000.png on trial no: 1
# error downloading 00010270_004.png on trial no: 1
# error downloading 00019067_000.png on trial no: 2
# error downloading 00019067_000.png on trial no: 3
# error downloading 00019067_000.png on trial no: 4
# error downloading 00019067_000.png on trial no: 5
# error downloading 00019067_000.png on trial no: 6
# error downloading 00019067_000.png on trial no: 7
# error downloading 00019067_000.png on trial no: 8
# error downloading 00019067_000.png on trial no: 9
# error downloading 00019067_000.png on trial no: 10
# error downloading 00019067_000.png on trial no: 11
# error downloading 00019067_000.png on trial no: 12
# error downloading 00019067_000.png on trial no: 13
# error downloading 00019067_000.png on trial no: 14
# error downloading 00019067_000.png on trial no: 15
# error downloading 00010270_004.png on trial no: 2
# error downloading 00010270_004.png on trial no: 3
# error downloading 00010270_004.png on trial no: 4
# error downloading 00010270_004.png on trial no: 5
# error downloading 00010270_004.png on trial no: 6
# error downloading 00010270_004.png on trial no: 7
# error downloading 00010270_004.png on trial no: 8
# error downloading 00010270_004.png on trial no: 9
# error downloading 00010270_004.png on trial no: 10
# error downloading 00010270_004.png on trial no: 11
# error downloading 00010270_004.png on trial no: 12
# error downloading 00010270_004.png on trial no: 13
# error downloading 00010270_004.png on trial no: 14
# error downloading 00010270_004.png on trial no: 15
# error downloading 00026374_003.png on trial no: 1
# error downloading 00003875_004.png on trial no: 1
# error downloading 00003875_004.png on trial no: 2
# error downloading 00003875_004.png on trial no: 3
# error downloading 00003875_004.png on trial no: 4
# error downloading 00003875_004.png on trial no: 5
# error downloading 00003875_004.png on trial no: 6
# error downloading 00003875_004.png on trial no: 7
# error downloading 00003875_004.png on trial no: 8
# error downloading 00003875_004.png on trial no: 9
# error downloading 00003875_004.png on trial no: 10
# error downloading 00003875_004.png on trial no: 11
# error downloading 00003875_004.png on trial no: 12
# error downloading 00003875_004.png on trial no: 13
# error downloading 00003875_004.png on trial no: 14
# error downloading 00003875_004.png on trial no: 15
# error downloading 00007961_000.png on trial no: 1
# error downloading 00007961_000.png on trial no: 2
# error downloading 00007961_000.png on trial no: 3
# error downloading 00007961_000.png on trial no: 4
# error downloading 00007961_000.png on trial no: 5
# error downloading 00007961_000.png on trial no: 6
# error downloading 00007961_000.png on trial no: 7
# error downloading 00007961_000.png on trial no: 8
# error downloading 00007961_000.png on trial no: 9
# error downloading 00007961_000.png on trial no: 10
# error downloading 00007961_000.png on trial no: 11
# error downloading 00007961_000.png on trial no: 12
# error downloading 00007961_000.png on trial no: 13
# error downloading 00007961_000.png on trial no: 14
# error downloading 00007961_000.png on trial no: 15
# error downloading 00026374_003.png on trial no: 2
# error downloading 00026374_003.png on trial no: 3
# error downloading 00026374_003.png on trial no: 4
# error downloading 00026374_003.png on trial no: 5
# error downloading 00026374_003.png on trial no: 6
# error downloading 00026374_003.png on trial no: 7
# error downloading 00026374_003.png on trial no: 8
# error downloading 00026374_003.png on trial no: 9
# error downloading 00026374_003.png on trial no: 10
# error downloading 00026374_003.png on trial no: 11
# error downloading 00026374_003.png on trial no: 12
# error downloading 00026374_003.png on trial no: 13
# error downloading 00026374_003.png on trial no: 14
# error downloading 00026374_003.png on trial no: 15
# error downloading 00007273_000.png on trial no: 1
# error downloading 00007273_000.png on trial no: 2
# error downloading 00007273_000.png on trial no: 3
# error downloading 00007273_000.png on trial no: 4
# error downloading 00007273_000.png on trial no: 5
# error downloading 00007273_000.png on trial no: 6
# error downloading 00007273_000.png on trial no: 7
# error downloading 00007273_000.png on trial no: 8
# error downloading 00007273_000.png on trial no: 9
# error downloading 00007273_000.png on trial no: 10
# error downloading 00007273_000.png on trial no: 11
# error downloading 00007273_000.png on trial no: 12
# error downloading 00007273_000.png on trial no: 13
# error downloading 00007273_000.png on trial no: 14
# error downloading 00007273_000.png on trial no: 15
# error downloading 00013973_000.png on trial no: 1
# error downloading 00013973_000.png on trial no: 2
# error downloading 00013973_000.png on trial no: 3
# error downloading 00013973_000.png on trial no: 4
# error downloading 00013973_000.png on trial no: 5
# error downloading 00013973_000.png on trial no: 6
# error downloading 00013973_000.png on trial no: 7
# error downloading 00013973_000.png on trial no: 8
# error downloading 00013973_000.png on trial no: 9
# error downloading 00013973_000.png on trial no: 10
# error downloading 00013973_000.png on trial no: 11
# error downloading 00013973_000.png on trial no: 12
# error downloading 00013973_000.png on trial no: 13
# error downloading 00013973_000.png on trial no: 14
# error downloading 00013973_000.png on trial no: 15
# error downloading 00027066_000.png on trial no: 1
# error downloading 00015369_003.png on trial no: 1
# error downloading 00015369_003.png on trial no: 2
# error downloading 00015369_003.png on trial no: 3
# error downloading 00015369_003.png on trial no: 4
# error downloading 00015369_003.png on trial no: 5
# error downloading 00015369_003.png on trial no: 6
# error downloading 00015369_003.png on trial no: 7
# error downloading 00015369_003.png on trial no: 8
# error downloading 00015369_003.png on trial no: 9
# error downloading 00015369_003.png on trial no: 10
# error downloading 00015369_003.png on trial no: 11
# error downloading 00015369_003.png on trial no: 12
# error downloading 00015369_003.png on trial no: 13
# error downloading 00015369_003.png on trial no: 14
# error downloading 00015369_003.png on trial no: 15
# error downloading 00027066_000.png on trial no: 2
# error downloading 00027066_000.png on trial no: 3
# error downloading 00027066_000.png on trial no: 4
# error downloading 00027066_000.png on trial no: 5
# error downloading 00027066_000.png on trial no: 6
# error downloading 00027066_000.png on trial no: 7
# error downloading 00027066_000.png on trial no: 8
# error downloading 00027066_000.png on trial no: 9
# error downloading 00027066_000.png on trial no: 10
# error downloading 00027066_000.png on trial no: 11
# error downloading 00027066_000.png on trial no: 12
# error downloading 00027066_000.png on trial no: 13
# error downloading 00027066_000.png on trial no: 14
# error downloading 00027066_000.png on trial no: 15
# error downloading 00005692_000.png on trial no: 1
# error downloading 00005692_000.png on trial no: 2
# error downloading 00005692_000.png on trial no: 3
# error downloading 00005692_000.png on trial no: 4
# error downloading 00005692_000.png on trial no: 5
# error downloading 00005692_000.png on trial no: 6
# error downloading 00005692_000.png on trial no: 7
# error downloading 00005692_000.png on trial no: 8
# error downloading 00005692_000.png on trial no: 9
# error downloading 00005692_000.png on trial no: 10
# error downloading 00005692_000.png on trial no: 11
# error downloading 00005692_000.png on trial no: 12
# error downloading 00005692_000.png on trial no: 13
# error downloading 00005692_000.png on trial no: 14
# error downloading 00005692_000.png on trial no: 15
# error downloading 00023056_000.png on trial no: 1
# error downloading 00006030_001.png on trial no: 1
# error downloading 00006030_001.png on trial no: 2
# error downloading 00006030_001.png on trial no: 3
# error downloading 00006030_001.png on trial no: 4
# error downloading 00006030_001.png on trial no: 5
# error downloading 00006030_001.png on trial no: 6
# error downloading 00006030_001.png on trial no: 7
# error downloading 00006030_001.png on trial no: 8
# error downloading 00006030_001.png on trial no: 9
# error downloading 00006030_001.png on trial no: 10
# error downloading 00006030_001.png on trial no: 11
# error downloading 00006030_001.png on trial no: 12
# error downloading 00006030_001.png on trial no: 13
# error downloading 00006030_001.png on trial no: 14
# error downloading 00006030_001.png on trial no: 15
# error downloading 00023056_000.png on trial no: 2
# error downloading 00023056_000.png on trial no: 3
# error downloading 00023056_000.png on trial no: 4
# error downloading 00023056_000.png on trial no: 5
# error downloading 00023056_000.png on trial no: 6
# error downloading 00023056_000.png on trial no: 7
# error downloading 00023056_000.png on trial no: 8
# error downloading 00023056_000.png on trial no: 9
# error downloading 00023056_000.png on trial no: 10
# error downloading 00023056_000.png on trial no: 11
# error downloading 00023056_000.png on trial no: 12
# error downloading 00023056_000.png on trial no: 13
# error downloading 00023056_000.png on trial no: 14
# error downloading 00023056_000.png on trial no: 15
# error downloading 00013187_005.png on trial no: 1
# error downloading 00005567_018.png on trial no: 1
# error downloading 00005567_018.png on trial no: 2
# error downloading 00005567_018.png on trial no: 3
# error downloading 00005567_018.png on trial no: 4
# error downloading 00005567_018.png on trial no: 5
# error downloading 00005567_018.png on trial no: 6
# error downloading 00005567_018.png on trial no: 7
# error downloading 00005567_018.png on trial no: 8
# error downloading 00005567_018.png on trial no: 9
# error downloading 00005567_018.png on trial no: 10
# error downloading 00005567_018.png on trial no: 11
# error downloading 00005567_018.png on trial no: 12
# error downloading 00005567_018.png on trial no: 13
# error downloading 00005567_018.png on trial no: 14
# error downloading 00005567_018.png on trial no: 15
# error downloading 00013187_005.png on trial no: 2
# error downloading 00013187_005.png on trial no: 3
# error downloading 00013187_005.png on trial no: 4
# error downloading 00013187_005.png on trial no: 5
# error downloading 00013187_005.png on trial no: 6
# error downloading 00013187_005.png on trial no: 7
# error downloading 00013187_005.png on trial no: 8
# error downloading 00013187_005.png on trial no: 9
# error downloading 00013187_005.png on trial no: 10
# error downloading 00013187_005.png on trial no: 11
# error downloading 00013187_005.png on trial no: 12
# error downloading 00013187_005.png on trial no: 13
# error downloading 00013187_005.png on trial no: 14
# error downloading 00013187_005.png on trial no: 15
# error downloading 00026349_001.png on trial no: 1
# error downloading 00026349_001.png on trial no: 2
# error downloading 00026349_001.png on trial no: 3
# error downloading 00026349_001.png on trial no: 4
# error downloading 00026349_001.png on trial no: 5
# error downloading 00026349_001.png on trial no: 6
# error downloading 00026349_001.png on trial no: 7
# error downloading 00026349_001.png on trial no: 8
# error downloading 00026349_001.png on trial no: 9
# error downloading 00026349_001.png on trial no: 10
# error downloading 00026349_001.png on trial no: 11
# error downloading 00026349_001.png on trial no: 12
# error downloading 00026349_001.png on trial no: 13
# error downloading 00026349_001.png on trial no: 14
# error downloading 00026349_001.png on trial no: 15
# error downloading 00002331_005.png on trial no: 1
# error downloading 00002331_005.png on trial no: 2
# error downloading 00002331_005.png on trial no: 3
# error downloading 00002331_005.png on trial no: 4
# error downloading 00002331_005.png on trial no: 5
# error downloading 00002331_005.png on trial no: 6
# error downloading 00002331_005.png on trial no: 7
# error downloading 00002331_005.png on trial no: 8
# error downloading 00002331_005.png on trial no: 9
# error downloading 00002331_005.png on trial no: 10
# error downloading 00002331_005.png on trial no: 11
# error downloading 00002331_005.png on trial no: 12
# error downloading 00002331_005.png on trial no: 13
# error downloading 00002331_005.png on trial no: 14
# error downloading 00002331_005.png on trial no: 15
# error downloading 00007534_029.png on trial no: 1
# error downloading 00007534_029.png on trial no: 2error downloading 00012697_006.png on trial no: 1
# error downloading 00012697_006.png on trial no: 2
# error downloading 00012697_006.png on trial no: 3
# error downloading 00012697_006.png on trial no: 4
# error downloading 00012697_006.png on trial no: 5
# error downloading 00012697_006.png on trial no: 6
# error downloading 00012697_006.png on trial no: 7
# error downloading 00012697_006.png on trial no: 8
# error downloading 00012697_006.png on trial no: 9
# error downloading 00012697_006.png on trial no: 10
# error downloading 00012697_006.png on trial no: 11
# error downloading 00012697_006.png on trial no: 12
# error downloading 00012697_006.png on trial no: 13
# error downloading 00012697_006.png on trial no: 14
# error downloading 00012697_006.png on trial no: 15
#
# error downloading 00007534_029.png on trial no: 3
# error downloading 00007534_029.png on trial no: 4
# error downloading 00016871_004.png on trial no: 1error downloading 00007534_029.png on trial no: 5error downloading 00004006_024.png on trial no: 1
#
# error downloading 00007534_029.png on trial no: 6
# error downloading 00007534_029.png on trial no: 7
# error downloading 00007534_029.png on trial no: 8
# error downloading 00007534_029.png on trial no: 9
# error downloading 00007534_029.png on trial no: 10
# error downloading 00007534_029.png on trial no: 11
# error downloading 00007534_029.png on trial no: 12
# error downloading 00007534_029.png on trial no: 13
# error downloading 00007534_029.png on trial no: 14
# error downloading 00007534_029.png on trial no: 15
#
# error downloading 00004006_024.png on trial no: 2
# error downloading 00004006_024.png on trial no: 3
# error downloading 00004006_024.png on trial no: 4
# error downloading 00004006_024.png on trial no: 5
# error downloading 00004006_024.png on trial no: 6
# error downloading 00004006_024.png on trial no: 7
# error downloading 00004006_024.png on trial no: 8
# error downloading 00016871_004.png on trial no: 2error downloading 00004006_024.png on trial no: 9
# error downloading 00004006_024.png on trial no: 10
# error downloading 00004006_024.png on trial no: 11
# error downloading 00004006_024.png on trial no: 12
# error downloading 00004006_024.png on trial no: 13
# error downloading 00004006_024.png on trial no: 14
# error downloading 00004006_024.png on trial no: 15
#
# error downloading 00016871_004.png on trial no: 3
# error downloading 00016871_004.png on trial no: 4
# error downloading 00016871_004.png on trial no: 5
# error downloading 00016871_004.png on trial no: 6
# error downloading 00016871_004.png on trial no: 7
# error downloading 00016871_004.png on trial no: 8
# error downloading 00016871_004.png on trial no: 9
# error downloading 00016871_004.png on trial no: 10
# error downloading 00016871_004.png on trial no: 11
# error downloading 00016871_004.png on trial no: 12
# error downloading 00016871_004.png on trial no: 13
# error downloading 00016871_004.png on trial no: 14
# error downloading 00016871_004.png on trial no: 15
# error downloading 00024362_000.png on trial no: 1
# error downloading 00024362_000.png on trial no: 2
# error downloading 00024362_000.png on trial no: 3
# error downloading 00024362_000.png on trial no: 4
# error downloading 00027077_000.png on trial no: 1
# error downloading 00024362_000.png on trial no: 5
# error downloading 00027627_002.png on trial no: 1
# error downloading 00027627_002.png on trial no: 2
# error downloading 00027627_002.png on trial no: 3
# error downloading 00027627_002.png on trial no: 4
# error downloading 00027627_002.png on trial no: 5
# error downloading 00027077_000.png on trial no: 2error downloading 00024362_000.png on trial no: 6
# error downloading 00027077_000.png on trial no: 3
# error downloading 00027077_000.png on trial no: 4
# error downloading 00027077_000.png on trial no: 5
# error downloading 00027077_000.png on trial no: 6
# error downloading 00027077_000.png on trial no: 7
# error downloading 00022546_000.png on trial no: 1
# error downloading 00022546_000.png on trial no: 2
# error downloading 00022546_000.png on trial no: 3
# error downloading 00022546_000.png on trial no: 4
# error downloading 00022546_000.png on trial no: 5
# error downloading 00022546_000.png on trial no: 6
# error downloading 00022546_000.png on trial no: 7
# error downloading 00022546_000.png on trial no: 8
# error downloading 00022546_000.png on trial no: 9
# error downloading 00022546_000.png on trial no: 10
# error downloading 00022546_000.png on trial no: 11
# error downloading 00022546_000.png on trial no: 12
# error downloading 00022546_000.png on trial no: 13
# error downloading 00022546_000.png on trial no: 14
# error downloading 00022546_000.png on trial no: 15
# error downloading 00027627_002.png on trial no: 6error downloading 00027077_000.png on trial no: 8
# error downloading 00027077_000.png on trial no: 9
# error downloading 00027077_000.png on trial no: 10
# error downloading 00027077_000.png on trial no: 11
# error downloading 00027077_000.png on trial no: 12
# error downloading 00027077_000.png on trial no: 13
# error downloading 00027077_000.png on trial no: 14
# error downloading 00027077_000.png on trial no: 15
#
# error downloading 00027627_002.png on trial no: 7
# error downloading 00027627_002.png on trial no: 8
# error downloading 00027627_002.png on trial no: 9
# error downloading 00027627_002.png on trial no: 10
# error downloading 00027627_002.png on trial no: 11
# error downloading 00027627_002.png on trial no: 12
# error downloading 00027627_002.png on trial no: 13
# error downloading 00027627_002.png on trial no: 14
# error downloading 00027627_002.png on trial no: 15
#
# error downloading 00021653_002.png on trial no: 1
# error downloading 00024362_000.png on trial no: 7
# error downloading 00024362_000.png on trial no: 8
# error downloading 00024362_000.png on trial no: 9
# error downloading 00024362_000.png on trial no: 10
# error downloading 00024362_000.png on trial no: 11
# error downloading 00024362_000.png on trial no: 12
# error downloading 00024362_000.png on trial no: 13
# error downloading 00024362_000.png on trial no: 14
# error downloading 00024362_000.png on trial no: 15
# error downloading 00021653_002.png on trial no: 2
# error downloading 00021653_002.png on trial no: 3
# error downloading 00021653_002.png on trial no: 4
# error downloading 00021653_002.png on trial no: 5
# error downloading 00021653_002.png on trial no: 6
# error downloading 00021653_002.png on trial no: 7
# error downloading 00021653_002.png on trial no: 8
# error downloading 00021653_002.png on trial no: 9
# error downloading 00021653_002.png on trial no: 10
# error downloading 00021653_002.png on trial no: 11
# error downloading 00021653_002.png on trial no: 12
# error downloading 00021653_002.png on trial no: 13
# error downloading 00021653_002.png on trial no: 14
# error downloading 00021653_002.png on trial no: 15
# error downloading 00010862_001.png on trial no: 1
# error downloading 00004191_001.png on trial no: 1
# error downloading 00004191_001.png on trial no: 2
# error downloading 00004191_001.png on trial no: 3
# ...
# error downloading 00014367_001.png on trial no: 3
# error downloading 00014367_001.png on trial no: 4
# error downloading 00014367_001.png on trial no: 5
# error downloading 00014367_001.png on trial no: 6
# error downloading 00014367_001.png on trial no: 7
# error downloading 00014367_001.png on trial no: 8
# error downloading 00014367_001.png on trial no: 9
# error downloading 00014367_001.png on trial no: 10
# error downloading 00014367_001.png on trial no: 11
# error downloading 00014367_001.png on trial no: 12
# error downloading 00014367_001.png on trial no: 13
# error downloading 00014367_001.png on trial no: 14
# error downloading 00014367_001.png on trial no: 15
# error downloading 00021219_008.png on trial no: 1
# error downloading 00021219_008.png on trial no: 2
# error downloading 00021219_008.png on trial no: 3
# error downloading 00021219_008.png on trial no: 4
# error downloading 00021219_008.png on trial no: 5
# error downloading 00021219_008.png on trial no: 6
# error downloading 00021219_008.png on trial no: 7
# error downloading 00021219_008.png on trial no: 8
# error downloading 00021219_008.png on trial no: 9
# error downloading 00021219_008.png on trial no: 10
# error downloading 00021219_008.png on trial no: 11
# error downloading 00021219_008.png on trial no: 12
# error downloading 00021219_008.png on trial no: 13
# error downloading 00021219_008.png on trial no: 14
# error downloading 00021219_008.png on trial no: 15
# error downloading 00019200_000.png on trial no: 1
# error downloading 00026024_012.png on trial no: 1
# error downloading 00026024_012.png on trial no: 2
# error downloading 00026024_012.png on trial no: 3
# error downloading 00026024_012.png on trial no: 4
# error downloading 00026024_012.png on trial no: 5
# error downloading 00026024_012.png on trial no: 6
# error downloading 00026024_012.png on trial no: 7
# error downloading 00026024_012.png on trial no: 8
# error downloading 00026024_012.png on trial no: 9
# error downloading 00026024_012.png on trial no: 10
# error downloading 00026024_012.png on trial no: 11
# error downloading 00026024_012.png on trial no: 12
# error downloading 00026024_012.png on trial no: 13
# error downloading 00026024_012.png on trial no: 14
# error downloading 00026024_012.png on trial no: 15
# error downloading 00019200_000.png on trial no: 2
# error downloading 00019200_000.png on trial no: 3
# error downloading 00019200_000.png on trial no: 4
# error downloading 00019200_000.png on trial no: 5
# error downloading 00019200_000.png on trial no: 6
# error downloading 00019200_000.png on trial no: 7
# error downloading 00019200_000.png on trial no: 8
# error downloading 00019200_000.png on trial no: 9
# error downloading 00019200_000.png on trial no: 10
# error downloading 00019200_000.png on trial no: 11
# error downloading 00019200_000.png on trial no: 12
# error downloading 00019200_000.png on trial no: 13
# error downloading 00019200_000.png on trial no: 14
# error downloading 00019200_000.png on trial no: 15
# error downloading 00020673_018.png on trial no: 1
# error downloading 00020673_018.png on trial no: 2
# error downloading 00020673_018.png on trial no: 3
# error downloading 00020673_018.png on trial no: 4
# error downloading 00020673_018.png on trial no: 5
# error downloading 00020673_018.png on trial no: 6
# error downloading 00020673_018.png on trial no: 7
# error downloading 00020673_018.png on trial no: 8
# error downloading 00020673_018.png on trial no: 9
# error downloading 00020673_018.png on trial no: 10
# error downloading 00020673_018.png on trial no: 11
# error downloading 00020673_018.png on trial no: 12
# error downloading 00020673_018.png on trial no: 13
# error downloading 00020673_018.png on trial no: 14
# error downloading 00020673_018.png on trial no: 15
# error downloading 00014688_013.png on trial no: 1
# error downloading 00014688_013.png on trial no: 2
# error downloading 00014688_013.png on trial no: 3
# error downloading 00014688_013.png on trial no: 4error downloading 00012278_000.png on trial no: 1
# error downloading 00026994_003.png on trial no: 1
# error downloading 00026994_003.png on trial no: 2
# error downloading 00026994_003.png on trial no: 3
# error downloading 00026994_003.png on trial no: 4
# error downloading 00026994_003.png on trial no: 5
# error downloading 00026994_003.png on trial no: 6
# error downloading 00026994_003.png on trial no: 7
# error downloading 00026994_003.png on trial no: 8
# error downloading 00026994_003.png on trial no: 9
# error downloading 00026994_003.png on trial no: 10
# error downloading 00026994_003.png on trial no: 11
# error downloading 00026994_003.png on trial no: 12
# error downloading 00026994_003.png on trial no: 13
# error downloading 00026994_003.png on trial no: 14
# error downloading 00026994_003.png on trial no: 15
#
# error downloading 00014688_013.png on trial no: 5
# error downloading 00014688_013.png on trial no: 6
# error downloading 00014688_013.png on trial no: 7
# error downloading 00014688_013.png on trial no: 8
# error downloading 00014688_013.png on trial no: 9
# error downloading 00014688_013.png on trial no: 10
# error downloading 00014688_013.png on trial no: 11
# error downloading 00014688_013.png on trial no: 12
# error downloading 00014688_013.png on trial no: 13
# error downloading 00014688_013.png on trial no: 14
# error downloading 00014688_013.png on trial no: 15
# error downloading 00012278_000.png on trial no: 2
# error downloading 00012278_000.png on trial no: 3
# error downloading 00012278_000.png on trial no: 4
# error downloading 00012278_000.png on trial no: 5
# error downloading 00012278_000.png on trial no: 6
# error downloading 00012278_000.png on trial no: 7
# error downloading 00012278_000.png on trial no: 8
# error downloading 00012278_000.png on trial no: 9
# error downloading 00012278_000.png on trial no: 10
# error downloading 00012278_000.png on trial no: 11
# error downloading 00012278_000.png on trial no: 12
# error downloading 00012278_000.png on trial no: 13
# error downloading 00012278_000.png on trial no: 14
# error downloading 00012278_000.png on trial no: 15
# error downloading 00000080_002.png on trial no: 1
# error downloading 00000080_002.png on trial no: 2
# error downloading 00000080_002.png on trial no: 3
# error downloading 00000080_002.png on trial no: 4
# error downloading 00000080_002.png on trial no: 5
# error downloading 00000080_002.png on trial no: 6
# error downloading 00000080_002.png on trial no: 7
# error downloading 00000080_002.png on trial no: 8
# error downloading 00000080_002.png on trial no: 9
# error downloading 00000080_002.png on trial no: 10
# error downloading 00000080_002.png on trial no: 11
# error downloading 00000080_002.png on trial no: 12
# error downloading 00000080_002.png on trial no: 13
# error downloading 00000080_002.png on trial no: 14
# error downloading 00000080_002.png on trial no: 15
# error downloading 00016190_002.png on trial no: 1
# error downloading 00016190_002.png on trial no: 2
# error downloading 00016190_002.png on trial no: 3
# error downloading 00016190_002.png on trial no: 4
# error downloading 00016190_002.png on trial no: 5
# error downloading 00016190_002.png on trial no: 6
# error downloading 00016190_002.png on trial no: 7
# error downloading 00016190_002.png on trial no: 8
# error downloading 00016190_002.png on trial no: 9
# error downloading 00016190_002.png on trial no: 10
# error downloading 00016190_002.png on trial no: 11
# error downloading 00016190_002.png on trial no: 12
# error downloading 00016190_002.png on trial no: 13
# error downloading 00016190_002.png on trial no: 14
# error downloading 00016190_002.png on trial no: 15
# error downloading 00014006_016.png on trial no: 1
# error downloading 00014006_016.png on trial no: 2
# error downloading 00014006_016.png on trial no: 3error downloading 00008625_001.png on trial no: 1
# error downloading 00008625_001.png on trial no: 2
# error downloading 00008625_001.png on trial no: 3
# error downloading 00008625_001.png on trial no: 4
# error downloading 00008625_001.png on trial no: 5
# error downloading 00008625_001.png on trial no: 6
# error downloading 00008625_001.png on trial no: 7
# error downloading 00008625_001.png on trial no: 8
# error downloading 00008625_001.png on trial no: 9
# error downloading 00008625_001.png on trial no: 10
# error downloading 00008625_001.png on trial no: 11
# error downloading 00008625_001.png on trial no: 12
# error downloading 00008625_001.png on trial no: 13
# error downloading 00008625_001.png on trial no: 14
# error downloading 00008625_001.png on trial no: 15
#
# error downloading 00014006_016.png on trial no: 4
# error downloading 00014006_016.png on trial no: 5
# error downloading 00014006_016.png on trial no: 6
# error downloading 00014006_016.png on trial no: 7
# error downloading 00014006_016.png on trial no: 8
# error downloading 00014006_016.png on trial no: 9
# error downloading 00014006_016.png on trial no: 10
# error downloading 00014006_016.png on trial no: 11
# error downloading 00014006_016.png on trial no: 12
# error downloading 00014006_016.png on trial no: 13error downloading 00017554_000.png on trial no: 1
# error downloading 00017554_000.png on trial no: 2
# error downloading 00017554_000.png on trial no: 3
# error downloading 00017554_000.png on trial no: 4
# error downloading 00017554_000.png on trial no: 5
# error downloading 00017554_000.png on trial no: 6
# error downloading 00017554_000.png on trial no: 7
# error downloading 00017554_000.png on trial no: 8
# error downloading 00017554_000.png on trial no: 9
# error downloading 00017554_000.png on trial no: 10
# error downloading 00017554_000.png on trial no: 11
# error downloading 00017554_000.png on trial no: 12
# error downloading 00017554_000.png on trial no: 13
# error downloading 00017554_000.png on trial no: 14
# error downloading 00017554_000.png on trial no: 15
# error downloading 00009644_020.png on trial no: 1
# error downloading 00009644_020.png on trial no: 2
# error downloading 00009644_020.png on trial no: 3
# error downloading 00009644_020.png on trial no: 4
# error downloading 00009644_020.png on trial no: 5
# error downloading 00009644_020.png on trial no: 6
# error downloading 00009644_020.png on trial no: 7
# error downloading 00009644_020.png on trial no: 8
# error downloading 00009644_020.png on trial no: 9
# error downloading 00009644_020.png on trial no: 10
# error downloading 00009644_020.png on trial no: 11
# error downloading 00009644_020.png on trial no: 12
# error downloading 00009644_020.png on trial no: 13
# error downloading 00009644_020.png on trial no: 14
# error downloading 00009644_020.png on trial no: 15
#
# error downloading 00014006_016.png on trial no: 14
# error downloading 00014006_016.png on trial no: 15
# error downloading 00018521_004.png on trial no: 1
# error downloading 00021276_005.png on trial no: 1
# error downloading 00021276_005.png on trial no: 2
# error downloading 00021276_005.png on trial no: 3
# error downloading 00021276_005.png on trial no: 4
# error downloading 00021276_005.png on trial no: 5
# error downloading 00021276_005.png on trial no: 6
# error downloading 00021276_005.png on trial no: 7
# error downloading 00021276_005.png on trial no: 8
# error downloading 00021276_005.png on trial no: 9
# error downloading 00021276_005.png on trial no: 10
# error downloading 00021276_005.png on trial no: 11
# error downloading 00021276_005.png on trial no: 12
# error downloading 00021276_005.png on trial no: 13
# error downloading 00021276_005.png on trial no: 14
# error downloading 00021276_005.png on trial no: 15
# error downloading 00018521_004.png on trial no: 2
# error downloading 00018521_004.png on trial no: 3
# error downloading 00018521_004.png on trial no: 4
# error downloading 00018521_004.png on trial no: 5
# error downloading 00018521_004.png on trial no: 6
# error downloading 00018521_004.png on trial no: 7
# error downloading 00018521_004.png on trial no: 8
# error downloading 00018521_004.png on trial no: 9
# error downloading 00018521_004.png on trial no: 10
# error downloading 00018521_004.png on trial no: 11
# error downloading 00018521_004.png on trial no: 12
# error downloading 00018521_004.png on trial no: 13
# error downloading 00018521_004.png on trial no: 14
# error downloading 00018521_004.png on trial no: 15
# error downloading 00005206_000.png on trial no: 1
# error downloading 00005206_000.png on trial no: 2
# error downloading 00020379_002.png on trial no: 1
# error downloading 00020379_002.png on trial no: 2
# error downloading 00020379_002.png on trial no: 3
# error downloading 00020379_002.png on trial no: 4
# error downloading 00020379_002.png on trial no: 5
# error downloading 00020379_002.png on trial no: 6
# error downloading 00020379_002.png on trial no: 7
# error downloading 00020379_002.png on trial no: 8
# error downloading 00020379_002.png on trial no: 9
# error downloading 00020379_002.png on trial no: 10
# error downloading 00005206_000.png on trial no: 3
# error downloading 00005206_000.png on trial no: 4
# error downloading 00005206_000.png on trial no: 5
# error downloading 00005206_000.png on trial no: 6
# error downloading 00005206_000.png on trial no: 7
# error downloading 00005206_000.png on trial no: 8
# error downloading 00005206_000.png on trial no: 9
# error downloading 00005206_000.png on trial no: 10
# error downloading 00005206_000.png on trial no: 11
# error downloading 00005206_000.png on trial no: 12
# error downloading 00005206_000.png on trial no: 13
# error downloading 00005206_000.png on trial no: 14
# error downloading 00005206_000.png on trial no: 15
# error downloading 00001956_003.png on trial no: 1
# error downloading 00001956_003.png on trial no: 2
# error downloading 00001956_003.png on trial no: 3
# error downloading 00001956_003.png on trial no: 4
# error downloading 00001956_003.png on trial no: 5
# error downloading 00001956_003.png on trial no: 6
# error downloading 00001956_003.png on trial no: 7
# error downloading 00001956_003.png on trial no: 8
# error downloading 00001956_003.png on trial no: 9
# error downloading 00001956_003.png on trial no: 10
# error downloading 00001956_003.png on trial no: 11
# error downloading 00001956_003.png on trial no: 12
# error downloading 00001956_003.png on trial no: 13
# error downloading 00001956_003.png on trial no: 14
# error downloading 00001956_003.png on trial no: 15
# error downloading 00020379_002.png on trial no: 11
# error downloading 00020379_002.png on trial no: 12
# error downloading 00020379_002.png on trial no: 13
# error downloading 00020379_002.png on trial no: 14
# error downloading 00020379_002.png on trial no: 15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-dd52b57eb392> in <module>()
#      23                 break
#      24
# ---> 25   xray_class.df["Image Index"].apply(lambda x: Downloader(x, LOCAL_IMAGES_LOCATION + x.split('/')[-1] ).start() )
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-9-dd52b57eb392> in <lambda>(x)
#      23                 break
#      24
# ---> 25   xray_class.df["Image Index"].apply(lambda x: Downloader(x, LOCAL_IMAGES_LOCATION + x.split('/')[-1] ).start() )
#
# /usr/lib/python3.6/threading.py in start(self)
#     849                 del _limbo[self]
#     850             raise
# --> 851         self._started.wait()
#     852
#     853     def run(self):
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %%
#  let's now append the full system path
xray_class.df["Image Index"] = xray_class.df["Image Index"].apply(lambda x : LOCAL_IMAGES_LOCATION + x.split('/')[-1])
xray_class.df.head()
# Out:
#                             Image Index  ... y_pixel_spacing
# 21828  /content/images/00006763_000.png  ...  0.171000
# 76932  /content/images/00024141_000.png  ...  0.143000
# 86712  /content/images/00028639_001.png  ...  0.194311
# 49540  /content/images/00014768_004.png  ...  0.168000
# 81020  /content/images/00026243_000.png  ...  0.143000
#
# [5 rows x 11 columns]

# %% [markdown]
# # Pre-processing of images and label
# - split dataframe accordingly with equal numbers of labels in test and train
# - batches image
# - show image

# %%
# Split them into training and validation using NUM_IMAGES 
train_df, valid_df, test_df = xray_class.get_test_train_split_data(len(xray_class.df))

print(train_df.labels.value_counts())
print("="*50)
print(valid_df.labels.value_counts())
print("="*50)
print(test_df.labels.value_counts())
# Out:
# Pneumothorax    4242
# No Finding      4241
# Name: labels, dtype: int64
# ==================================================
# No Finding      854
# Pneumothorax    842
# Name: labels, dtype: int64
# ==================================================
# Pneumothorax    218
# No Finding      207
# Name: labels, dtype: int64

# %%
# Create training and validation data batches using ImageDataGenerator
train_data = xray_class.generate_image(train_df, True)
val_data   = xray_class.generate_image(valid_df)
test_data   = xray_class.generate_image(test_df)
# Out:
# Found 8483 validated image filenames belonging to 2 classes.
# Found 1696 validated image filenames belonging to 2 classes.
# Found 425 validated image filenames belonging to 2 classes.

# %%
train_images, train_labels = next(train_data)
xray_class.show_25_images(train_images, train_labels)

# %% [markdown]
# # Perform model trainining
# - fit our data using Categorical classification with metrics of accuracy and optimization Adam
# - validate data
# - save our model

# %%
if xray_class.model_exist(SICKNESS):
    model = xray_class.model_exist(SICKNESS)
    a, b = model.evaluate(test_data)
else:
    model, stop = xray_class.train_model(EPOCH, train_data, val_data)
    a, b = model.evaluate(test_data)

    filename= f"{SICKNESS}_{b:.2f}"
    xray_class.save_model(model, filename)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 1001)              55875273
# _________________________________________________________________
# dense (Dense)                (None, 512)               513024
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 56,651,979
# Trainable params: 776,706
# Non-trainable params: 55,875,273
# _________________________________________________________________
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 266 steps, validate for 53 steps
# Epoch 1/1000
# 266/266 [==============================] - 249s 934ms/step - loss: 0.8759 - accuracy: 0.6095 - val_loss: 0.6266 - val_accuracy: 0.6456
# Epoch 2/1000
# 266/266 [==============================] - 228s 856ms/step - loss: 0.6298 - accuracy: 0.6596 - val_loss: 0.5891 - val_accuracy: 0.6869
# Epoch 3/1000
# 266/266 [==============================] - 228s 856ms/step - loss: 0.6172 - accuracy: 0.6741 - val_loss: 0.5897 - val_accuracy: 0.7129
# Epoch 4/1000
# 266/266 [==============================] - 224s 843ms/step - loss: 0.5948 - accuracy: 0.6902 - val_loss: 0.5626 - val_accuracy: 0.7288
# Epoch 5/1000
# 266/266 [==============================] - 221s 832ms/step - loss: 0.5847 - accuracy: 0.7051 - val_loss: 0.5708 - val_accuracy: 0.7347
# Epoch 6/1000
# 266/266 [==============================] - 226s 850ms/step - loss: 0.5854 - accuracy: 0.7027 - val_loss: 0.5640 - val_accuracy: 0.7235
# Epoch 7/1000
# 266/266 [==============================] - 231s 868ms/step - loss: 0.5836 - accuracy: 0.7010 - val_loss: 0.5512 - val_accuracy: 0.7258
# Epoch 8/1000
# 266/266 [==============================] - 233s 875ms/step - loss: 0.5750 - accuracy: 0.7038 - val_loss: 0.5514 - val_accuracy: 0.7282
# Epoch 9/1000
# 266/266 [==============================] - 229s 860ms/step - loss: 0.5739 - accuracy: 0.7015 - val_loss: 0.5578 - val_accuracy: 0.7388
# Epoch 10/1000
# 266/266 [==============================] - 226s 851ms/step - loss: 0.5702 - accuracy: 0.7088 - val_loss: 0.5778 - val_accuracy: 0.7311
# Epoch 11/1000
# 266/266 [==============================] - 223s 839ms/step - loss: 0.5637 - accuracy: 0.7173 - val_loss: 0.5591 - val_accuracy: 0.7335
# Epoch 12/1000
# 266/266 [==============================] - 217s 815ms/step - loss: 0.5594 - accuracy: 0.7173 - val_loss: 0.5686 - val_accuracy: 0.7093
# Epoch 13/1000
# 266/266 [==============================] - 218s 820ms/step - loss: 0.5553 - accuracy: 0.7166 - val_loss: 0.5450 - val_accuracy: 0.7317
# Epoch 14/1000
# 266/266 [==============================] - 211s 794ms/step - loss: 0.5548 - accuracy: 0.7165 - val_loss: 0.5446 - val_accuracy: 0.7417
# Epoch 15/1000
# 266/266 [==============================] - 207s 777ms/step - loss: 0.5559 - accuracy: 0.7196 - val_loss: 0.5699 - val_accuracy: 0.7364
# Epoch 16/1000
# 266/266 [==============================] - 208s 780ms/step - loss: 0.5636 - accuracy: 0.7154 - val_loss: 0.5652 - val_accuracy: 0.7465
# Epoch 17/1000
# 266/266 [==============================] - 206s 775ms/step - loss: 0.5591 - accuracy: 0.7210 - val_loss: 0.5682 - val_accuracy: 0.7093
# Epoch 18/1000
# 266/266 [==============================] - 207s 778ms/step - loss: 0.5532 - accuracy: 0.7292 - val_loss: 0.5633 - val_accuracy: 0.7241
# Epoch 19/1000
# 266/266 [==============================] - 206s 774ms/step - loss: 0.5597 - accuracy: 0.7174 - val_loss: 0.5412 - val_accuracy: 0.7406
# Epoch 20/1000
# 266/266 [==============================] - 205s 770ms/step - loss: 0.5570 - accuracy: 0.7159 - val_loss: 0.5484 - val_accuracy: 0.7465
# Epoch 21/1000
# 266/266 [==============================] - 203s 763ms/step - loss: 0.5585 - accuracy: 0.7186 - val_loss: 0.5671 - val_accuracy: 0.7170
# Epoch 22/1000
# 266/266 [==============================] - 202s 761ms/step - loss: 0.5539 - accuracy: 0.7140 - val_loss: 0.5446 - val_accuracy: 0.7471
# Epoch 23/1000
# 266/266 [==============================] - 202s 761ms/step - loss: 0.5521 - accuracy: 0.7188 - val_loss: 0.5693 - val_accuracy: 0.7294
# Epoch 24/1000
# 266/266 [==============================] - 204s 766ms/step - loss: 0.5454 - accuracy: 0.7256 - val_loss: 0.5527 - val_accuracy: 0.7476
# Epoch 25/1000
# 266/266 [==============================] - 204s 765ms/step - loss: 0.5456 - accuracy: 0.7293 - val_loss: 0.5661 - val_accuracy: 0.7459
# Epoch 26/1000
# 266/266 [==============================] - 199s 750ms/step - loss: 0.5496 - accuracy: 0.7238 - val_loss: 0.5534 - val_accuracy: 0.7471
# Epoch 27/1000
# 266/266 [==============================] - 198s 745ms/step - loss: 0.5528 - accuracy: 0.7266 - val_loss: 0.5524 - val_accuracy: 0.7435
# Epoch 28/1000
# 266/266 [==============================] - 199s 748ms/step - loss: 0.5503 - accuracy: 0.7263 - val_loss: 0.5478 - val_accuracy: 0.7553
# Epoch 29/1000
# 266/266 [==============================] - 199s 746ms/step - loss: 0.5402 - accuracy: 0.7308 - val_loss: 0.5708 - val_accuracy: 0.7494
# Epoch 30/1000
# 266/266 [==============================] - 197s 741ms/step - loss: 0.5507 - accuracy: 0.7264 - val_loss: 0.5488 - val_accuracy: 0.7453
# Epoch 31/1000
# 266/266 [==============================] - 198s 746ms/step - loss: 0.5535 - accuracy: 0.7262 - val_loss: 0.5482 - val_accuracy: 0.7518
# Epoch 32/1000
# 266/266 [==============================] - 198s 745ms/step - loss: 0.5425 - accuracy: 0.7318 - val_loss: 0.5737 - val_accuracy: 0.7235
# Epoch 33/1000
# 266/266 [==============================] - 198s 744ms/step - loss: 0.5537 - accuracy: 0.7216 - val_loss: 0.5519 - val_accuracy: 0.7482
# Epoch 34/1000
# 266/266 [==============================] - 198s 745ms/step - loss: 0.5486 - accuracy: 0.7292 - val_loss: 0.5460 - val_accuracy: 0.7429
# Epoch 35/1000
# 266/266 [==============================] - 198s 744ms/step - loss: 0.5524 - accuracy: 0.7324 - val_loss: 0.5496 - val_accuracy: 0.7482
# Epoch 36/1000
# 266/266 [==============================] - 197s 742ms/step - loss: 0.5569 - accuracy: 0.7231 - val_loss: 0.5561 - val_accuracy: 0.7482
# Epoch 37/1000
# 266/266 [==============================] - 199s 747ms/step - loss: 0.5433 - accuracy: 0.7258 - val_loss: 0.5305 - val_accuracy: 0.7547
# Epoch 38/1000
# 266/266 [==============================] - 198s 744ms/step - loss: 0.5441 - accuracy: 0.7226 - val_loss: 0.5542 - val_accuracy: 0.7488
# Epoch 39/1000
# 266/266 [==============================] - 197s 742ms/step - loss: 0.5440 - accuracy: 0.7329 - val_loss: 0.5486 - val_accuracy: 0.7394
# Epoch 40/1000
# 266/266 [==============================] - 197s 742ms/step - loss: 0.5461 - accuracy: 0.7260 - val_loss: 0.5594 - val_accuracy: 0.7441
# Epoch 41/1000
# 266/266 [==============================] - 198s 743ms/step - loss: 0.5492 - accuracy: 0.7293 - val_loss: 0.5513 - val_accuracy: 0.7518
# Epoch 42/1000
# 266/266 [==============================] - 198s 745ms/step - loss: 0.5407 - accuracy: 0.7321 - val_loss: 0.5439 - val_accuracy: 0.7494
# Epoch 43/1000
# 266/266 [==============================] - 197s 742ms/step - loss: 0.5396 - accuracy: 0.7392 - val_loss: 0.5207 - val_accuracy: 0.7541
# Epoch 44/1000
# 266/266 [==============================] - 198s 744ms/step - loss: 0.5434 - accuracy: 0.7305 - val_loss: 0.5533 - val_accuracy: 0.7482
# Epoch 45/1000
# 266/266 [==============================] - 197s 742ms/step - loss: 0.5424 - accuracy: 0.7275 - val_loss: 0.5664 - val_accuracy: 0.7335
# Epoch 46/1000
# 266/266 [==============================] - 197s 740ms/step - loss: 0.5398 - accuracy: 0.7321 - val_loss: 0.5333 - val_accuracy: 0.7547
# Epoch 47/1000
# 207/266 [======================>.......] - ETA: 38s - loss: 0.5426 - accuracy: 0.7315

# %%
acc = model.history.history['accuracy']
val_acc = model.history.history['val_accuracy']

loss=model.history.history['loss']
val_loss=model.history.history['val_loss']

epochs_range = range(stop.stopped_epoch + 1)

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Post processing
# - Predict our validation data
# - load tensorboard
# - Show images and percentage of accuracy for those prediction

# %%
# Make predictions on the validation data (not used to train on)
predictions = model.predict(test_data, verbose=1)

# %%
# Let's check a few predictions and their different values
test_images, test_labels = next(test_data)

i_multiplier = 0
num_rows = 3
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(5*2*num_cols, 5*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  xray_class.plot_pred(prediction_probabilities=predictions,
            labels=test_labels,
            images=test_images,
            n=i+i_multiplier)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  xray_class.plot_pred_conf(prediction_probabilities=predictions,
                labels=test_labels,
                n=i+i_multiplier)
plt.tight_layout(h_pad=1.0)
plt.show()

# %% [markdown]
# # Evaluating our model
# - confusion matrix
# - classification report
# - loss and accuracy

# %%
print(f"Loss : {a}, Accuracy: {b}")

# %%
y_test = [xray_class.get_label(x) for x in predictions] # convert [0,25, 0.75] -> "No Finding/Effusion"
y_val = [xray_class.get_unique_labels()[x] for x in test_data.labels]


xray_class.generate_confusion_matrix(y_test, y_val)

# %%
xray_class.generate_classification_report(y_test, y_val)
