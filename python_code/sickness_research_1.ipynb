# %%
# !pip uninstall tensorflow -y
# !pip install tensorflow==2.1

# %%
# Run this one if using google colab
from google.colab import drive
import sys
import os

drive.mount('/content/gdrive')
sys.path.append("/content/xray_code/python_code")

if not os.path.exists("/content/xray_code"):
  # !cp -r "/content/gdrive/My Drive/xray_code/" "/content/xray_code"
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %load_ext autoreload
# %autoreload 2

from utils import *
from ml_utils import XrayTF
from tqdm import tqdm_notebook as tqdm
from threading import Thread
from constants import LOCAL_IMAGES_LOCATION

import urllib.request as req
import matplotlib.pyplot as plt
import numpy as np
import time
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Load csv if exist, if not get the original one and parse it

# %%
"""
SICKNESS = "Infiltration"
SICKNESS = "Pneumonia"
SICKNESS = "Mass"
SICKNESS = "Pneumothorax"
"""

SICKNESS = "Pneumothorax"
csv_file = "normalized_xray_without_full_path.csv"
csv_file_full_path = f'/content/gdrive/My Drive/xray_code/sheet/{csv_file}'

IMAGE_SIZE = 224
BATCH_SIZE = 32
EPOCH = 1000

pd.set_option('display.max_colwidth', -1)


# take existing if it exist
if os.path.exists(csv_file_full_path):
    df = pd.read_csv(csv_file_full_path)
    xray_class = XrayTF(df, IMAGE_SIZE, BATCH_SIZE)
    xray_class.prepend_image_full_path()
else:
    df = get_data_sheet()
    df = normalize_data_frame(df)
    xray_class = XrayTF(df, IMAGE_SIZE, BATCH_SIZE)
    xray_class.prepend_image_full_path()
    xray_class.df.to_csv(csv_file_full_path, index=False)

xray_class.df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   app.launch_new_instance()
#                                                             Image Index  ... y_pixel_spacing
# 0  https://xrayimages.nyc3.digitaloceanspaces.com/v0.1/00000001_000.png  ...  0.143
# 1  https://xrayimages.nyc3.digitaloceanspaces.com/v0.1/00000002_000.png  ...  0.171
# 2  https://xrayimages.nyc3.digitaloceanspaces.com/v0.1/00000003_000.png  ...  0.143
# 3  https://xrayimages.nyc3.digitaloceanspaces.com/v0.1/00000003_001.png  ...  0.168
# 4  https://xrayimages.nyc3.digitaloceanspaces.com/v0.1/00000003_002.png  ...  0.168
#
# [5 rows x 11 columns]

# %% [markdown]
# # Analyze our data set
# - take a look at the distribution
# - prepare data before splitting to test and train
#   - Get image based on xray Position
#   - Select a sickness and balance them
# - Generate Age histogram

# %%
print(xray_class.df["View Position"].value_counts())
print("="*50)
print(xray_class.df.labels.value_counts())
# Out:
# PA    81630
# AP    59907
# Name: View Position, dtype: int64
# ==================================================
# No Finding            60361
# Infiltration          19894
# Effusion              13317
# Atelectasis           11559
# Nodule                6331
# Mass                  5782
# Pneumothorax          5302
# Consolidation         4667
# Pleural_Thickening    3385
# Cardiomegaly          2776
# Emphysema             2516
# Edema                 2303
# Fibrosis              1686
# Pneumonia             1431
# Hernia                227
# Name: labels, dtype: int64

# %%
# Pick a sickness
xray_class.use_one_label(SICKNESS, balance=True)

# Verify how balanced our data is
print(xray_class.df.labels.value_counts())
print(xray_class.df["Patient Gender"].value_counts())
# Out:
# Pneumothorax    5302
# No Finding      5302
# Name: labels, dtype: int64
# M    5695
# F    4909
# Name: Patient Gender, dtype: int64

# %%
xray_class.df["Patient Age"].hist(bins=30).set_xlim(0,100)
# Out:
# (0.0, 100.0)

# %% [markdown]
# # Download our data
# - Parallel download from digital ocean
# - prepend system path after download

# %%
# !rm -rf /content/images
if not os.path.exists(LOCAL_IMAGES_LOCATION):
  # !mkdir /content/images

  class Downloader(Thread):
    def __init__(self, file_url, save_path):
        Thread.__init__(self)
        self.file_url = file_url
        self.save_path = save_path

    def run(self):
        remaining_download_tries = 15

        while remaining_download_tries > 0:
            try:
                req.urlretrieve(self.file_url, self.save_path)
                time.sleep(0.1)
            except:
                print("error downloading " + self.file_url +
                      " on trial no: " + str(16 - remaining_download_tries))
                remaining_download_tries = remaining_download_tries - 1
                continue
            else:
                break

  xray_class.df["Image Index"].apply(lambda x: Downloader(x, LOCAL_IMAGES_LOCATION + x.split('/')[-1] ).start() )

# %%
#  let's now append the full system path
xray_class.df["Image Index"] = xray_class.df["Image Index"].apply(lambda x : LOCAL_IMAGES_LOCATION + x.split('/')[-1])
xray_class.df.head()
# Out:
#                             Image Index  ... y_pixel_spacing
# 21828  /content/images/00006763_000.png  ...  0.171000
# 76932  /content/images/00024141_000.png  ...  0.143000
# 86712  /content/images/00028639_001.png  ...  0.194311
# 49540  /content/images/00014768_004.png  ...  0.168000
# 81020  /content/images/00026243_000.png  ...  0.143000
#
# [5 rows x 11 columns]

# %% [markdown]
# # Pre-processing of images and label
# - split dataframe accordingly with equal numbers of labels in test and train
# - batches image
# - show image

# %%
# Split them into training and validation using NUM_IMAGES 
train_df, valid_df, test_df = xray_class.get_test_train_split_data(len(xray_class.df))

print(train_df.labels.value_counts())
print("="*50)
print(valid_df.labels.value_counts())
print("="*50)
print(test_df.labels.value_counts())
# Out:
# Pneumothorax    4242
# No Finding      4241
# Name: labels, dtype: int64
# ==================================================
# No Finding      854
# Pneumothorax    842
# Name: labels, dtype: int64
# ==================================================
# Pneumothorax    218
# No Finding      207
# Name: labels, dtype: int64

# %%
# Create training and validation data batches using ImageDataGenerator
train_data = xray_class.generate_image(train_df, True)
val_data   = xray_class.generate_image(valid_df)
test_data   = xray_class.generate_image(test_df)
# Out:
# Found 8483 validated image filenames belonging to 2 classes.
# Found 1696 validated image filenames belonging to 2 classes.
# Found 425 validated image filenames belonging to 2 classes.

# %%
train_images, train_labels = next(train_data)
xray_class.show_25_images(train_images, train_labels)

# %% [markdown]
# # Perform model trainining
# - fit our data using Categorical classification with metrics of accuracy and optimization Adam
# - validate data
# - save our model

# %%
if xray_class.model_exist(SICKNESS):
    model = xray_class.model_exist(SICKNESS)
    a, b = model.evaluate(test_data)
else:
    model, stop = xray_class.train_model(EPOCH, train_data, val_data)
    a, b = model.evaluate(test_data)

    filename= f"{SICKNESS}_{b:.2f}"
    xray_class.save_model(model, filename)
# Out:
# 266/266 [==============================] - 216s 814ms/step - loss: 0.6058 - accuracy: 0.6858 - val_loss: 0.6086 - val_accuracy: 0.7017
# Epoch 4/1000
# 266/266 [==============================] - 216s 812ms/step - loss: 0.5975 - accuracy: 0.6975 - val_loss: 0.5730 - val_accuracy: 0.7258
# Epoch 5/1000
# 266/266 [==============================] - 216s 811ms/step - loss: 0.5899 - accuracy: 0.6983 - val_loss: 0.5651 - val_accuracy: 0.7022
# Epoch 26/1000
# 266/266 [==============================] - 215s 809ms/step - loss: 0.5510 - accuracy: 0.7273 - val_loss: 0.5666 - val_accuracy: 0.7435
# Epoch 27/1000
# 266/266 [==============================] - 215s 808ms/step - loss: 0.5496 - accuracy: 0.7272 - val_loss: 0.5627 - val_accuracy: 0.7577
# Epoch 28/1000
# 266/266 [==============================] - 215s 807ms/step - loss: 0.5556 - accuracy: 0.7282 - val_loss: 0.5494 - val_accuracy: 0.7465
# Epoch 29/1000
# 266/266 [==============================] - 215s 807ms/step - loss: 0.5501 - accuracy: 0.7283 - val_loss: 0.5587 - val_accuracy: 0.7370
# Epoch 30/1000
# 266/266 [==============================] - 214s 806ms/step - loss: 0.5497 - accuracy: 0.7306 - val_loss: 0.5445 - val_accuracy: 0.7358
# Epoch 31/1000
# 266/266 [==============================] - 214s 806ms/step - loss: 0.5469 - accuracy: 0.7305 - val_loss: 0.5609 - val_accuracy: 0.7488
# Epoch 32/1000
# 266/266 [==============================] - 214s 805ms/step - loss: 0.5420 - accuracy: 0.7341 - val_loss: 0.5531 - val_accuracy: 0.7512
# Epoch 33/1000
# 266/266 [==============================] - 214s 805ms/step - loss: 0.5456 - accuracy: 0.7316 - val_loss: 0.5612 - val_accuracy: 0.7406
# Epoch 34/1000
# 266/266 [==============================] - 214s 804ms/step - loss: 0.5429 - accuracy: 0.7304 - val_loss: 0.5465 - val_accuracy: 0.7471
# Epoch 35/1000
# 266/266 [==============================] - 215s 808ms/step - loss: 0.5422 - accuracy: 0.7298 - val_loss: 0.5571 - val_accuracy: 0.7370
# Epoch 36/1000
# 266/266 [==============================] - 215s 809ms/step - loss: 0.5398 - accuracy: 0.7388 - val_loss: 0.5476 - val_accuracy: 0.7541
# Epoch 37/1000
# 266/266 [==============================] - 215s 808ms/step - loss: 0.5452 - accuracy: 0.7323 - val_loss: 0.5539 - val_accuracy: 0.7476
# Epoch 38/1000
# 266/266 [==============================] - 215s 808ms/step - loss: 0.5448 - accuracy: 0.7329 - val_loss: 0.5538 - val_accuracy: 0.7441
# Epoch 39/1000
# 266/266 [==============================] - 214s 806ms/step - loss: 0.5436 - accuracy: 0.7332 - val_loss: 0.5284 - val_accuracy: 0.7476
# Epoch 40/1000
# 266/266 [==============================] - 217s 817ms/step - loss: 0.5393 - accuracy: 0.7337 - val_loss: 0.5391 - val_accuracy: 0.7482
# Epoch 41/1000
# 266/266 [==============================] - 216s 814ms/step - loss: 0.5353 - accuracy: 0.7387 - val_loss: 0.5340 - val_accuracy: 0.7512
# Epoch 42/1000
# 266/266 [==============================] - 222s 835ms/step - loss: 0.5446 - accuracy: 0.7322 - val_loss: 0.5502 - val_accuracy: 0.7400
# Epoch 43/1000
# 266/266 [==============================] - 224s 841ms/step - loss: 0.5459 - accuracy: 0.7337 - val_loss: 0.5341 - val_accuracy: 0.7476
# Epoch 44/1000
# 266/266 [==============================] - 228s 856ms/step - loss: 0.5372 - accuracy: 0.7387 - val_loss: 0.5284 - val_accuracy: 0.7559
# Epoch 45/1000
# 266/266 [==============================] - 230s 866ms/step - loss: 0.5465 - accuracy: 0.7285 - val_loss: 0.5523 - val_accuracy: 0.7471
# Epoch 46/1000
# 266/266 [==============================] - 231s 869ms/step - loss: 0.5423 - accuracy: 0.7270 - val_loss: 0.5453 - val_accuracy: 0.7524
# Epoch 47/1000
# 266/266 [==============================] - 233s 876ms/step - loss: 0.5409 - accuracy: 0.7342 - val_loss: 0.5552 - val_accuracy: 0.7506
# Epoch 48/1000
# 266/266 [==============================] - 232s 874ms/step - loss: 0.5470 - accuracy: 0.7297 - val_loss: 0.5407 - val_accuracy: 0.7423
# Epoch 49/1000
# 266/266 [==============================] - 233s 877ms/step - loss: 0.5369 - accuracy: 0.7333 - val_loss: 0.5383 - val_accuracy: 0.7553
# Epoch 50/1000
# 266/266 [==============================] - 233s 875ms/step - loss: 0.5375 - accuracy: 0.7369 - val_loss: 0.5570 - val_accuracy: 0.7512
# Epoch 51/1000
# 266/266 [==============================] - 233s 877ms/step - loss: 0.5408 - accuracy: 0.7298 - val_loss: 0.5333 - val_accuracy: 0.7447
# Epoch 52/1000
# 266/266 [==============================] - 226s 848ms/step - loss: 0.5460 - accuracy: 0.7271 - val_loss: 0.5429 - val_accuracy: 0.7471
# Epoch 53/1000
# 266/266 [==============================] - 221s 831ms/step - loss: 0.5411 - accuracy: 0.7350 - val_loss: 0.5448 - val_accuracy: 0.7358
# Epoch 54/1000
# 266/266 [==============================] - 229s 862ms/step - loss: 0.5398 - accuracy: 0.7339 - val_loss: 0.5597 - val_accuracy: 0.7441
# Epoch 55/1000
# 266/266 [==============================] - 227s 855ms/step - loss: 0.5338 - accuracy: 0.7321 - val_loss: 0.5468 - val_accuracy: 0.7512
# Epoch 56/1000
# 266/266 [==============================] - 227s 854ms/step - loss: 0.5397 - accuracy: 0.7352 - val_loss: 0.5353 - val_accuracy: 0.7653
# Epoch 57/1000
# 235/266 [=========================>....] - ETA: 23s - loss: 0.5330 - accuracy: 0.7347

# %%
acc = model.history.history['accuracy']
val_acc = model.history.history['val_accuracy']

loss=model.history.history['loss']
val_loss=model.history.history['val_loss']

epochs_range = range(stop.stopped_epoch + 1)

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Post processing
# - Predict our validation data
# - load tensorboard
# - Show images and percentage of accuracy for those prediction

# %%
# Make predictions on the validation data (not used to train on)
predictions = model.predict(test_data, verbose=1)

# %%
# Let's check a few predictions and their different values
test_images, test_labels = next(test_data)

i_multiplier = 0
num_rows = 3
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(5*2*num_cols, 5*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  xray_class.plot_pred(prediction_probabilities=predictions,
            labels=test_labels,
            images=test_images,
            n=i+i_multiplier)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  xray_class.plot_pred_conf(prediction_probabilities=predictions,
                labels=test_labels,
                n=i+i_multiplier)
plt.tight_layout(h_pad=1.0)
plt.show()

# %% [markdown]
# # Evaluating our model
# - confusion matrix
# - classification report
# - loss and accuracy

# %%
print(f"Loss : {a}, Accuracy: {b}")

# %%
y_test = [xray_class.get_label(x) for x in predictions] # convert [0,25, 0.75] -> "No Finding/Effusion"
y_val = [xray_class.get_unique_labels()[x] for x in test_data.labels]


xray_class.generate_confusion_matrix(y_test, y_val)

# %%
xray_class.generate_classification_report(y_test, y_val)
