# %%
# !pip uninstall tensorflow -y
# !pip install tensorflow==2.1

# %%
# %load_ext autoreload
# %autoreload 2

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
LOCAL_XRAY_LOCATION = "/content/xray_code"

import os
import shutil
if not os.path.exists(LOCAL_XRAY_LOCATION):
    shutil.copytree("/content/gdrive/My Drive/xray_code/",
                    LOCAL_XRAY_LOCATION)

# %%
"""
SICKNESS = "Infiltration"
SICKNESS = "Pneumonia"
SICKNESS = "Mass"
SICKNESS = "Pneumothorax"
"""

SICKNESS = "Pneumothorax"
csv_file = "normalized_xray_without_full_path.csv"
csv_file_full_path = f'{LOCAL_XRAY_LOCATION}/sheet/{csv_file}'

IMAGE_SIZE = 224
BATCH_SIZE = 32
EPOCH = 1000

python_file = f"{LOCAL_XRAY_LOCATION}/python_code/sickness_pipeline.py"

# !export IMAGE_URL=https://xrayimages.nyc3.digitaloceanspaces.com/v0.1/
# !python $python_file -img $IMAGE_SIZE -s $SICKNESS -b $BATCH_SIZE -f $csv_file_full_path -e $EPOCH
# Out:
# 2020-04-27 19:51:25.588043: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2020-04-27 19:51:25.588178: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2020-04-27 19:51:25.588204: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
# ...
