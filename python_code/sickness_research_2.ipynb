# %%
# !pip uninstall tensorflow -y
# !pip install tensorflow==2.1

# %%
# Run this one if using google colab
from google.colab import drive
import sys
import os

drive.mount('/content/gdrive')
sys.path.append("/content/xray_code/python_code")

if not os.path.exists("/content/xray_code"):
  # !cp -r "/content/gdrive/My Drive/xray_code/" "/content/xray_code"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %load_ext autoreload
# %autoreload 2

from utils import *
from ml_utils import XrayTF
from tqdm import tqdm_notebook as tqdm
from threading import Thread
from constants import LOCAL_IMAGES_LOCATION

import urllib.request as req
import matplotlib.pyplot as plt
import numpy as np
import time
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Load csv if exist, if not get the original one and parse it

# %%
"""
SICKNESS = "Infiltration"
SICKNESS = "Pneumonia"
SICKNESS = "Mass"
SICKNESS = "Pneumothorax"
"""

SICKNESS = "Pneumothorax"
csv_file = "normalized_xray_without_full_path.csv"
csv_file_full_path = f'/content/gdrive/My Drive/xray_code/sheet/{csv_file}'

IMAGE_SIZE = 224
BATCH_SIZE = 32
EPOCH = 1000

pd.set_option('display.max_colwidth', -1)


# take existing if it exist
if os.path.exists(csv_file_full_path):
    df = pd.read_csv(csv_file_full_path)
    xray_class = XrayTF(df, IMAGE_SIZE, BATCH_SIZE)
    xray_class.prepend_image_full_path()
else:
    df = get_data_sheet()
    df = normalize_data_frame(df)
    xray_class = XrayTF(df, IMAGE_SIZE, BATCH_SIZE)
    xray_class.prepend_image_full_path()
    xray_class.df.to_csv(csv_file_full_path, index=False)

xray_class.df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   app.launch_new_instance()
#                                                             Image Index  ... y_pixel_spacing
# 0  https://xrayimages.nyc3.digitaloceanspaces.com/v0.1/00000001_000.png  ...  0.143
# 1  https://xrayimages.nyc3.digitaloceanspaces.com/v0.1/00000002_000.png  ...  0.171
# 2  https://xrayimages.nyc3.digitaloceanspaces.com/v0.1/00000003_000.png  ...  0.143
# 3  https://xrayimages.nyc3.digitaloceanspaces.com/v0.1/00000003_001.png  ...  0.168
# 4  https://xrayimages.nyc3.digitaloceanspaces.com/v0.1/00000003_002.png  ...  0.168
#
# [5 rows x 11 columns]

# %% [markdown]
# # Analyze our data set
# - take a look at the distribution
# - prepare data before splitting to test and train
#   - Get image based on xray Position
#   - Select a sickness and balance them
# - Generate Age histogram

# %%
print(xray_class.df["View Position"].value_counts())
print("="*50)
print(xray_class.df.labels.value_counts())
# Out:
# PA    81630
# AP    59907
# Name: View Position, dtype: int64
# ==================================================
# No Finding            60361
# Infiltration          19894
# Effusion              13317
# Atelectasis           11559
# Nodule                6331
# Mass                  5782
# Pneumothorax          5302
# Consolidation         4667
# Pleural_Thickening    3385
# Cardiomegaly          2776
# Emphysema             2516
# Edema                 2303
# Fibrosis              1686
# Pneumonia             1431
# Hernia                227
# Name: labels, dtype: int64

# %%
# Pick a sickness
xray_class.use_one_label(SICKNESS, balance=True)

# Verify how balanced our data is
print(xray_class.df.labels.value_counts())
print(xray_class.df["Patient Gender"].value_counts())
# Out:
# No Finding      5302
# Pneumothorax    5302
# Name: labels, dtype: int64
# M    5695
# F    4909
# Name: Patient Gender, dtype: int64

# %%
xray_class.df["Patient Age"].hist(bins=30).set_xlim(0,100)
# Out:
# (0.0, 100.0)

# %% [markdown]
# # Download our data
# - Parallel download from digital ocean
# - prepend system path after download

# %%
# !rm -rf /content/images
if not os.path.exists(LOCAL_IMAGES_LOCATION):
  # !mkdir /content/images

  class Downloader(Thread):
    def __init__(self, file_url, save_path):
        Thread.__init__(self)
        self.file_url = file_url
        self.save_path = save_path

    def run(self):
        remaining_download_tries = 15

        while remaining_download_tries > 0:
            try:
                req.urlretrieve(self.file_url, self.save_path)
                time.sleep(0.1)
            except:
                print("error downloading " + self.file_url +
                      " on trial no: " + str(16 - remaining_download_tries))
                remaining_download_tries = remaining_download_tries - 1
                continue
            else:
                break

  xray_class.df["Image Index"].apply(lambda x: Downloader(x, LOCAL_IMAGES_LOCATION + x.split('/')[-1] ).start() )

# %%
#  let's now append the full system path
xray_class.df["Image Index"] = xray_class.df["Image Index"].apply(lambda x : LOCAL_IMAGES_LOCATION + x.split('/')[-1])
xray_class.df.head()
# Out:
#                             Image Index  ... y_pixel_spacing
# 21828  /content/images/00006763_000.png  ...  0.171000
# 76932  /content/images/00024141_000.png  ...  0.143000
# 86712  /content/images/00028639_001.png  ...  0.194311
# 49540  /content/images/00014768_004.png  ...  0.168000
# 81020  /content/images/00026243_000.png  ...  0.143000
#
# [5 rows x 11 columns]

# %% [markdown]
# # Pre-processing of images and label
# - split dataframe accordingly with equal numbers of labels in test and train
# - batches image
# - show image

# %%
# Split them into training and validation using NUM_IMAGES 
train_df, valid_df, test_df = xray_class.get_test_train_split_data(len(xray_class.df))

print(train_df.labels.value_counts())
print("="*50)
print(valid_df.labels.value_counts())
print("="*50)
print(test_df.labels.value_counts())
# Out:
# Pneumothorax    4242
# No Finding      4241
# Name: labels, dtype: int64
# ==================================================
# No Finding      854
# Pneumothorax    842
# Name: labels, dtype: int64
# ==================================================
# Pneumothorax    218
# No Finding      207
# Name: labels, dtype: int64

# %%
# Create training and validation data batches using ImageDataGenerator
train_data = xray_class.generate_image(train_df)
val_data   = xray_class.generate_image(valid_df)
test_data   = xray_class.generate_image(test_df)
# Out:
# Found 8483 validated image filenames belonging to 2 classes.
# Found 1696 validated image filenames belonging to 2 classes.
# Found 425 validated image filenames belonging to 2 classes.

# %%
train_images, train_labels = next(train_data)
xray_class.show_25_images(train_images, train_labels)

# %% [markdown]
# # Perform model trainining
# - fit our data using Categorical classification with metrics of accuracy and optimization Adam
# - validate data
# - save our model

# %%
if xray_class.model_exist(SICKNESS):
    model = xray_class.model_exist(SICKNESS)
    a, b = model.evaluate(test_data)
else:
    model, stop = xray_class.train_model(EPOCH, train_data, val_data)
    a, b = model.evaluate(test_data)

    filename= f"{SICKNESS}_{b:.2f}"
    xray_class.save_model(model, filename)
# Out:
# 266/266 [==============================] - 172s 648ms/step - loss: 0.8207 - accuracy: 0.6230 - val_loss: 0.5849 - val_accuracy: 0.7028
# Epoch 2/1000
# 266/266 [==============================] - 153s 576ms/step - loss: 0.5946 - accuracy: 0.6942 - val_loss: 0.5557 - val_accuracy: 0.7176
# Epoch 3/1000
# 266/266 [==============================] - 152s 573ms/step - loss: 0.5823 - accuracy: 0.7042 - val_loss: 0.5579 - val_accuracy: 0.7188
# Epoch 4/1000
# 266/266 [==============================] - 152s 573ms/step - loss: 0.5634 - accuracy: 0.7230 - val_loss: 0.5548 - val_accuracy: 0.7223
# Epoch 5/1000
# 266/266 [==============================] - 152s 571ms/step - loss: 0.5644 - accuracy: 0.7151 - val_loss: 0.5660 - val_accuracy: 0.7252
# Epoch 6/1000
# 266/266 [==============================] - 152s 572ms/step - loss: 0.5486 - accuracy: 0.7345 - val_loss: 0.5545 - val_accuracy: 0.7341
# Epoch 7/1000
# 266/266 [==============================] - 152s 571ms/step - loss: 0.5410 - accuracy: 0.7375 - val_loss: 0.5514 - val_accuracy: 0.7223
# Epoch 8/1000
# 266/266 [==============================] - 152s 571ms/step - loss: 0.5361 - accuracy: 0.7395 - val_loss: 0.5414 - val_accuracy: 0.7394
# Epoch 9/1000
# 266/266 [==============================] - 151s 569ms/step - loss: 0.5392 - accuracy: 0.7381 - val_loss: 0.5609 - val_accuracy: 0.7323
# Epoch 10/1000
# 266/266 [==============================] - 151s 569ms/step - loss: 0.5282 - accuracy: 0.7463 - val_loss: 0.5515 - val_accuracy: 0.7406
# Epoch 11/1000
# 266/266 [==============================] - 151s 567ms/step - loss: 0.5334 - accuracy: 0.7429 - val_loss: 0.5429 - val_accuracy: 0.7394
# Epoch 12/1000
# 266/266 [==============================] - 151s 569ms/step - loss: 0.5271 - accuracy: 0.7460 - val_loss: 0.5462 - val_accuracy: 0.7512
# Epoch 13/1000
# 266/266 [==============================] - 151s 568ms/step - loss: 0.5257 - accuracy: 0.7431 - val_loss: 0.5570 - val_accuracy: 0.7441
# Epoch 14/1000
# 266/266 [==============================] - 152s 571ms/step - loss: 0.5315 - accuracy: 0.7464 - val_loss: 0.5429 - val_accuracy: 0.7412
# Epoch 15/1000
# 266/266 [==============================] - 151s 568ms/step - loss: 0.5254 - accuracy: 0.7483 - val_loss: 0.5266 - val_accuracy: 0.7518
# Epoch 16/1000
# 266/266 [==============================] - 152s 572ms/step - loss: 0.5284 - accuracy: 0.7430 - val_loss: 0.5344 - val_accuracy: 0.7465
# Epoch 17/1000
# 266/266 [==============================] - 151s 569ms/step - loss: 0.5258 - accuracy: 0.7481 - val_loss: 0.5487 - val_accuracy: 0.7500
# Epoch 18/1000
# 266/266 [==============================] - 153s 573ms/step - loss: 0.5193 - accuracy: 0.7493 - val_loss: 0.5409 - val_accuracy: 0.7376
# Epoch 19/1000
# 266/266 [==============================] - 152s 570ms/step - loss: 0.5237 - accuracy: 0.7495 - val_loss: 0.5337 - val_accuracy: 0.7364
# Epoch 20/1000
# 266/266 [==============================] - 152s 571ms/step - loss: 0.5242 - accuracy: 0.7453 - val_loss: 0.5443 - val_accuracy: 0.7471
# Epoch 21/1000
# 266/266 [==============================] - 154s 579ms/step - loss: 0.5186 - accuracy: 0.7521 - val_loss: 0.5355 - val_accuracy: 0.7388
# Epoch 22/1000
# 266/266 [==============================] - 155s 582ms/step - loss: 0.5318 - accuracy: 0.7421 - val_loss: 0.5553 - val_accuracy: 0.7441
# Epoch 23/1000
# 266/266 [==============================] - 155s 583ms/step - loss: 0.5268 - accuracy: 0.7481 - val_loss: 0.5443 - val_accuracy: 0.7441
# Epoch 24/1000
# 266/266 [==============================] - 154s 580ms/step - loss: 0.5195 - accuracy: 0.7504 - val_loss: 0.5462 - val_accuracy: 0.7435
# Epoch 25/1000
# 266/266 [==============================] - 152s 573ms/step - loss: 0.5303 - accuracy: 0.7454 - val_loss: 0.5428 - val_accuracy: 0.7400
# Epoch 26/1000
# 266/266 [==============================] - 152s 572ms/step - loss: 0.5160 - accuracy: 0.7545 - val_loss: 0.5451 - val_accuracy: 0.7447
# Epoch 27/1000
# 266/266 [==============================] - 152s 572ms/step - loss: 0.5089 - accuracy: 0.7582 - val_loss: 0.5443 - val_accuracy: 0.7347
# Epoch 28/1000
# 266/266 [==============================] - 152s 572ms/step - loss: 0.5138 - accuracy: 0.7582 - val_loss: 0.5365 - val_accuracy: 0.7465
# Epoch 29/1000
# 266/266 [==============================] - 152s 572ms/step - loss: 0.5162 - accuracy: 0.7573 - val_loss: 0.5410 - val_accuracy: 0.7423
# Epoch 30/1000
# 266/266 [==============================] - 150s 565ms/step - loss: 0.5138 - accuracy: 0.7523 - val_loss: 0.5487 - val_accuracy: 0.7459
# Epoch 31/1000
# 266/266 [==============================] - 149s 559ms/step - loss: 0.5092 - accuracy: 0.7608 - val_loss: 0.5513 - val_accuracy: 0.7394
# Epoch 32/1000
# 266/266 [==============================] - 149s 559ms/step - loss: 0.5144 - accuracy: 0.7546 - val_loss: 0.5426 - val_accuracy: 0.7447
# Epoch 33/1000
# 266/266 [==============================] - 149s 560ms/step - loss: 0.5053 - accuracy: 0.7631 - val_loss: 0.5333 - val_accuracy: 0.7476
# Epoch 34/1000
# 266/266 [==============================] - 147s 554ms/step - loss: 0.5120 - accuracy: 0.7569 - val_loss: 0.5286 - val_accuracy: 0.7482
# Epoch 35/1000
# 266/266 [==============================] - 147s 552ms/step - loss: 0.5029 - accuracy: 0.7633 - val_loss: 0.5451 - val_accuracy: 0.7376
# Epoch 36/1000
# 266/266 [==============================] - 147s 552ms/step - loss: 0.5032 - accuracy: 0.7649 - val_loss: 0.5422 - val_accuracy: 0.7506
# Epoch 37/1000
# 266/266 [==============================] - 145s 547ms/step - loss: 0.4996 - accuracy: 0.7718 - val_loss: 0.5386 - val_accuracy: 0.7535
# Epoch 38/1000
# 266/266 [==============================] - 146s 548ms/step - loss: 0.5024 - accuracy: 0.7645 - val_loss: 0.5363 - val_accuracy: 0.7435
# Epoch 39/1000
# 266/266 [==============================] - 145s 546ms/step - loss: 0.5053 - accuracy: 0.7638 - val_loss: 0.5436 - val_accuracy: 0.7447
# Epoch 40/1000
# 266/266 [==============================] - 145s 547ms/step - loss: 0.4998 - accuracy: 0.7645 - val_loss: 0.5415 - val_accuracy: 0.7471
# Epoch 41/1000
# 266/266 [==============================] - 145s 545ms/step - loss: 0.5003 - accuracy: 0.7629 - val_loss: 0.5404 - val_accuracy: 0.7488
# Epoch 42/1000
# 266/266 [==============================] - 145s 544ms/step - loss: 0.5060 - accuracy: 0.7594 - val_loss: 0.5436 - val_accuracy: 0.7465
# Epoch 43/1000
# 266/266 [==============================] - 145s 545ms/step - loss: 0.5011 - accuracy: 0.7668 - val_loss: 0.5457 - val_accuracy: 0.7476
# Epoch 44/1000
# 266/266 [==============================] - 144s 542ms/step - loss: 0.5050 - accuracy: 0.7658 - val_loss: 0.5464 - val_accuracy: 0.7447
# Epoch 45/1000
# 266/266 [==============================] - 147s 554ms/step - loss: 0.4975 - accuracy: 0.7681 - val_loss: 0.5398 - val_accuracy: 0.7506
# Epoch 46/1000
# 266/266 [==============================] - 147s 553ms/step - loss: 0.4971 - accuracy: 0.7708 - val_loss: 0.5400 - val_accuracy: 0.7423
# Epoch 47/1000
# 266/266 [==============================] - 147s 551ms/step - loss: 0.4973 - accuracy: 0.7601 - val_loss: 0.5543 - val_accuracy: 0.7624
# Epoch 48/1000
# 266/266 [==============================] - 146s 547ms/step - loss: 0.4964 - accuracy: 0.7721 - val_loss: 0.5367 - val_accuracy: 0.7518
# Epoch 49/1000
# 266/266 [==============================] - 146s 549ms/step - loss: 0.4929 - accuracy: 0.7687 - val_loss: 0.5323 - val_accuracy: 0.7471
# Epoch 50/1000
# 266/266 [==============================] - 145s 546ms/step - loss: 0.4900 - accuracy: 0.7700 - val_loss: 0.5453 - val_accuracy: 0.7559
# Epoch 51/1000
# 266/266 [==============================] - 145s 545ms/step - loss: 0.4899 - accuracy: 0.7712 - val_loss: 0.5437 - val_accuracy: 0.7453
# Epoch 52/1000
# 266/266 [==============================] - 145s 544ms/step - loss: 0.4926 - accuracy: 0.7648 - val_loss: 0.5417 - val_accuracy: 0.7524
# Epoch 53/1000
# 266/266 [==============================] - 145s 546ms/step - loss: 0.4862 - accuracy: 0.7700 - val_loss: 0.5547 - val_accuracy: 0.7459
# Epoch 54/1000
# 266/266 [==============================] - 145s 544ms/step - loss: 0.4850 - accuracy: 0.7720 - val_loss: 0.5437 - val_accuracy: 0.7529
# Epoch 55/1000
# 266/266 [==============================] - 145s 545ms/step - loss: 0.4859 - accuracy: 0.7723 - val_loss: 0.5355 - val_accuracy: 0.7518
# Epoch 56/1000
# 266/266 [==============================] - 145s 546ms/step - loss: 0.4832 - accuracy: 0.7726 - val_loss: 0.5357 - val_accuracy: 0.7588
# Epoch 57/1000
# 266/266 [==============================] - 145s 547ms/step - loss: 0.4890 - accuracy: 0.7719 - val_loss: 0.5317 - val_accuracy: 0.7583
# Epoch 58/1000
# 266/266 [==============================] - 144s 541ms/step - loss: 0.4850 - accuracy: 0.7711 - val_loss: 0.5409 - val_accuracy: 0.7459
# Epoch 59/1000
# 266/266 [==============================] - 143s 539ms/step - loss: 0.4942 - accuracy: 0.7715 - val_loss: 0.5309 - val_accuracy: 0.7571
# Epoch 60/1000
# 266/266 [==============================] - 145s 544ms/step - loss: 0.4851 - accuracy: 0.7741 - val_loss: 0.5443 - val_accuracy: 0.7441
# Epoch 61/1000
# 266/266 [==============================] - 145s 547ms/step - loss: 0.4825 - accuracy: 0.7719 - val_loss: 0.5431 - val_accuracy: 0.7453
# Epoch 62/1000
# 266/266 [==============================] - 146s 551ms/step - loss: 0.4880 - accuracy: 0.7754 - val_loss: 0.5402 - val_accuracy: 0.7488
# Epoch 63/1000
# 266/266 [==============================] - 146s 547ms/step - loss: 0.4840 - accuracy: 0.7695 - val_loss: 0.5688 - val_accuracy: 0.7429
# Epoch 64/1000
# 266/266 [==============================] - 144s 543ms/step - loss: 0.4840 - accuracy: 0.7763 - val_loss: 0.5693 - val_accuracy: 0.7518
# Epoch 65/1000
# 266/266 [==============================] - 143s 537ms/step - loss: 0.4953 - accuracy: 0.7658 - val_loss: 0.5472 - val_accuracy: 0.7482
# Epoch 66/1000
# 266/266 [==============================] - 143s 538ms/step - loss: 0.4859 - accuracy: 0.7680 - val_loss: 0.5406 - val_accuracy: 0.7459
# Epoch 67/1000
# 266/266 [==============================] - 145s 545ms/step - loss: 0.4849 - accuracy: 0.7731 - val_loss: 0.5538 - val_accuracy: 0.7471
# Epoch 68/1000
# 266/266 [==============================] - 143s 538ms/step - loss: 0.4876 - accuracy: 0.7692 - val_loss: 0.5632 - val_accuracy: 0.7417
# Epoch 69/1000
# 266/266 [==============================] - 143s 536ms/step - loss: 0.4856 - accuracy: 0.7739 - val_loss: 0.5610 - val_accuracy: 0.7453
# Epoch 70/1000
# 266/266 [==============================] - 144s 541ms/step - loss: 0.4802 - accuracy: 0.7750 - val_loss: 0.5656 - val_accuracy: 0.7500
# Epoch 71/1000
# 266/266 [==============================] - 144s 540ms/step - loss: 0.4911 - accuracy: 0.7671 - val_loss: 0.5559 - val_accuracy: 0.7482
# Epoch 72/1000
# 266/266 [==============================] - 144s 541ms/step - loss: 0.4851 - accuracy: 0.7737 - val_loss: 0.5529 - val_accuracy: 0.7506
# Epoch 73/1000
# 266/266 [==============================] - 144s 540ms/step - loss: 0.4820 - accuracy: 0.7718 - val_loss: 0.5735 - val_accuracy: 0.7512
# Epoch 74/1000
# 266/266 [==============================] - 143s 537ms/step - loss: 0.4884 - accuracy: 0.7664 - val_loss: 0.5645 - val_accuracy: 0.7541
# Epoch 75/1000
# 266/266 [==============================] - 145s 546ms/step - loss: 0.4862 - accuracy: 0.7661 - val_loss: 0.5569 - val_accuracy: 0.7459
# Epoch 76/1000
# 266/266 [==============================] - 143s 539ms/step - loss: 0.4716 - accuracy: 0.7777 - val_loss: 0.5494 - val_accuracy: 0.7447
# Epoch 77/1000
# 265/266 [============================>.] - ETA: 0s - loss: 0.4750 - accuracy: 0.7780

# %%
acc = model.history.history['accuracy']
val_acc = model.history.history['val_accuracy']

loss=model.history.history['loss']
val_loss=model.history.history['val_loss']

epochs_range = range(stop.stopped_epoch + 1)

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Post processing
# - Predict our validation data
# - load tensorboard
# - Show images and percentage of accuracy for those prediction

# %%
# Make predictions on the validation data (not used to train on)
predictions = model.predict(test_data, verbose=1)

# %%
# Let's check a few predictions and their different values
test_images, test_labels = next(test_data)

i_multiplier = 0
num_rows = 3
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(5*2*num_cols, 5*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  xray_class.plot_pred(prediction_probabilities=predictions,
            labels=test_labels,
            images=test_images,
            n=i+i_multiplier)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  xray_class.plot_pred_conf(prediction_probabilities=predictions,
                labels=test_labels,
                n=i+i_multiplier)
plt.tight_layout(h_pad=1.0)
plt.show()

# %% [markdown]
# # Evaluating our model
# - confusion matrix
# - classification report
# - loss and accuracy

# %%
print(f"Loss : {a}, Accuracy: {b}")

# %%
y_test = [xray_class.get_label(x) for x in predictions] # convert [0,25, 0.75] -> "No Finding/Effusion"
y_val = [xray_class.get_unique_labels()[x] for x in test_data.labels]


xray_class.generate_confusion_matrix(y_test, y_val)

# %%
xray_class.generate_classification_report(y_test, y_val)
