# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils import *
from ml_utils import XrayTF
from tqdm import tqdm_notebook as tqdm

import matplotlib.pyplot as plt
import numpy as np
import os

# %% [markdown]
# # Load csv if exist, if not get the original one and parse it

# %%
"""
GENDER   = "F"
"""
SICKNESS = "Atelectasis"
POSITION = "PA"
csv_file = "../sheet/normalized_xray_data_with_no_finding.csv"


# take existing if it exist
if os.path.exists(csv_file):
    df = pd.read_csv(csv_file)
    xray_class = XrayTF(df)
else:
    df = get_data_sheet()
    df = normalize_data_frame(df)
    xray_class = XrayTF(df)
    xray_class.prepend_image_full_path()
    xray_class.df.to_csv(csv_file, index=False)

xray_class.df.head()
# Out:
#                                     Image Index        labels  Follow-up #  \
# 0  D:\xray\images\Cardiomegaly\00000001_000.png  Cardiomegaly            0
# 1    D:\xray\images\No Finding\00000002_000.png    No Finding            0
# 2        D:\xray\images\Hernia\00000003_000.png        Hernia            0
# 3        D:\xray\images\Hernia\00000003_001.png        Hernia            1
# 4        D:\xray\images\Hernia\00000003_002.png        Hernia            2
#
#    Patient ID  Patient Age Patient Gender View Position  image_width  \
# 0           1           58              M            PA         2682
# 1           2           81              M            PA         2500
# 2           3           81              F            PA         2582
# 3           3           74              F            PA         2500
# 4           3           75              F            PA         2048
#
#    image_width.1  x_pixel_spacing  y_pixel_spacing
# 0           2749            0.143            0.143
# 1           2048            0.171            0.171
# 2           2991            0.143            0.143
# 3           2048            0.168            0.168
# 4           2500            0.168            0.168

# %% [markdown]
# # Analyze our data set
# - balance our data set
# - take a look at the distribution
# - prepare data before splitting to test and train

# %%
# Pick a sickness
xray_class.use_one_label(SICKNESS, balance=True)

# Verify how balanced our data is
print(xray_class.df.labels.value_counts())
print(xray_class.df["Patient Gender"].value_counts())
print(xray_class.df["View Position"].value_counts())
# Out:
# No Finding     11559
# Atelectasis    11559
# Name: labels, dtype: int64
# M    13400
# F     9718
# Name: Patient Gender, dtype: int64
# PA    13272
# AP     9846
# Name: View Position, dtype: int64

# %%
xray_class.df["Patient Age"].hist(bins=100).set_xlim(0,100)
# Out:
# (0, 100)

# %%
# decide which one we want to take in terms of relating to other features.

"""
xray_class.df = xray_class.df[xray_class.df["Patient Gender"] == GENDER]
"""

xray_class.df = xray_class.df[xray_class.df["View Position"] == POSITION]

# %% [markdown]
# # Pre-processing of images and label
# - split dataframe accordingly with equal numbers of labels in test and train
# - batches image
# - show image

# %%
# Split them into training and validation using NUM_IMAGES 
train_df, valid_df = xray_class.get_test_train_split_data(len(xray_class.df))

# %%
# Create training and validation data batches using ImageDataGenerator
"""
train_data = xray_class.create_data_batches(X_train, y_train)
val_data = xray_class.create_data_batches(X_val, y_val, valid_data=True)
train_data.element_spec, val_data.element_spec
"""

train_data = xray_class.generate_image(train_df, augment=True)
val_data   = xray_class.generate_image(valid_df)
# Out:
# Found 10617 validated image filenames belonging to 2 classes.
# Found 2655 validated image filenames belonging to 2 classes.

# %%
"""
train_images, train_labels = next(train_data.as_numpy_iterator())
xray_class.show_25_images(train_images, train_labels)
"""

train_images, train_labels = next(train_data)
xray_class.show_25_images(train_images, train_labels)

# %% [markdown]
# # Perform model trainining
# - fit our data using Categorical classification with metrics of accuracy and optimization Adam
# - validate data
# - save our model

# %%
if xray_class.model_exist(SICKNESS, POSITION):
    model = xray_class.model_exist(SICKNESS, POSITION)
    a, b = model.evaluate(val_data)
else:
    model = xray_class.train_model(5, train_data, val_data) #(number of epoc, early stopping)
    a, b = model.evaluate(val_data)

    # save model
    xray_class.save_model(model, f"{SICKNESS}_{POSITION}_{round(a, 2)}_{round(b, 2)}")
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
#
17s - loss: 0.5332 - accuracy: 0.736 - ETA: 16s - loss: 0.5344 - accuracy: 0.736 - ETA: 16s - loss: 0.5356 - accuracy: 0.736 - ETA: 15s - loss: 0.5339 - accuracy: 0.738 - ETA: 14s - loss: 0.5320 - accuracy: 0.738 - ETA: 14s - loss: 0.5340 - accuracy: 0.737 - ETA: 13s - loss: 0.5343 - accuracy: 0.736 - ETA: 12s - loss: 0.5352 - accuracy: 0.737 - ETA: 12s - loss: 0.5339 - accuracy: 0.739 - ETA: 11s - loss: 0.5345 - accuracy: 0.738 - ETA: 11s - loss: 0.5341 - accuracy: 0.738 - ETA: 10s - loss: 0.5334 - accuracy: 0.739 - ETA: 9s - loss: 0.5359 - accuracy: 0.739 - ETA: 9s - loss: 0.5338 - accuracy: 0.74 - ETA: 8s - loss: 0.5319 - accuracy: 0.74 - ETA: 7s - loss: 0.5332 - accuracy: 0.73 - ETA: 7s - loss: 0.5337 - accuracy: 0.73 - ETA: 6s - loss: 0.5341 - accuracy: 0.73 - ETA: 6s - loss: 0.5340 - accuracy: 0.73 - ETA: 5s - loss: 0.5347 - accuracy: 0.73 - ETA: 4s - loss: 0.5362 - accuracy: 0.73 - ETA: 4s - loss: 0.5356 - accuracy: 0.73 - ETA: 3s - loss: 0.5362 - accuracy: 0.73 - ETA: 3s - loss: 0.5339 - accuracy: 0.73 - ETA: 2s - loss: 0.5342 - accuracy: 0.73 - ETA: 1s - loss: 0.5341 - accuracy: 0.73 - ETA: 1s - loss: 0.5339 - accuracy: 0.73 - ETA: 0s - loss: 0.5367 - accuracy: 0.73 - 52s 627ms/step - loss: 0.5350 - accuracy: 0.7375

# %%
# Make predictions on the validation data (not used to train on)
predictions = model.predict(val_data, verbose=1) # verbose shows us how long there is to go
# Out:
# 83/83 [==============================] - ETA: 1: - ETA: 1: - ETA: 1: - ETA: 1: - ETA: 57s - ETA: 57 - ETA: 56 - ETA: 54 - ETA: 52 - ETA: 51 - ETA: 49 - ETA: 47 - ETA: 46 - ETA: 45 - ETA: 43 - ETA: 42 - ETA: 42 - ETA: 41 - ETA: 40 - ETA: 40 - ETA: 39 - ETA: 38 - ETA: 37 - ETA: 37 - ETA: 36 - ETA: 35 - ETA: 34 - ETA: 33 - ETA: 33 - ETA: 32 - ETA: 31 - ETA: 30 - ETA: 30 - ETA: 29 - ETA: 29 - ETA: 28 - ETA: 27 - ETA: 27 - ETA: 26 - ETA: 25 - ETA: 25 - ETA: 24 - ETA: 23 - ETA: 23 - ETA: 22 - ETA: 21 - ETA: 21 - ETA: 20 - ETA: 19 - ETA: 19 - ETA: 18 - ETA: 18 - ETA: 17 - ETA: 17 - ETA: 16 - ETA: 16 - ETA: 15 - ETA: 14 - ETA: 14 - ETA: 13 - ETA: 13 - ETA: 12 - ETA: 11 - ETA: 11 - ETA: 10 - ETA: 9 - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 48s 584ms/step

# %%
# Let's check a few predictions and their different values
val_images, val_labels = next(val_data)

i_multiplier = 0
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(5*2*num_cols, 5*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  xray_class.plot_pred(prediction_probabilities=predictions,
            labels=val_labels,
            images=val_images,
            n=i+i_multiplier)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  xray_class.plot_pred_conf(prediction_probabilities=predictions,
                labels=val_labels,
                n=i+i_multiplier)
plt.tight_layout(h_pad=1.0)
plt.show()

# %% [markdown]
# # Evaluating our model
# - confusion matrix
# - classification report
# - loss and accuracy

# %%
acc = round(b,2)
loss = round(a,2)
print(f"Loss : {loss}, Accuracy: {acc}")
# Out:
# Loss : 0.54, Accuracy: 0.7400000095367432

# %%
y_test = [xray_class.get_label(x) for x in predictions] # convert [0,25, 0.75] -> "No Finding/Effusion"
y_val = [xray_class.get_unique_labels()[x] for x in val_data.labels]

xray_class.generate_confusion_matrix(y_test, y_val)

# %%
xray_class.generate_classification_report(y_test, y_val)
# Out:
#               precision    recall  f1-score   support
#
#  Atelectasis       0.63      0.56      0.60      1700
#   No Finding       0.35      0.42      0.38       955
#
#     accuracy                           0.51      2655
#    macro avg       0.49      0.49      0.49      2655
# weighted avg       0.53      0.51      0.52      2655
