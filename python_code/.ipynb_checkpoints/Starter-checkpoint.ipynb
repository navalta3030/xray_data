# %%
from utils import *
import pandas as pd

# df = get_data_sheet()
# df = normalize_data_frame(df)
# df.head()

df = pd.read_csv("../sheet/normalized_xray_data_with_no_finding.csv")
df["Imag"]
df.head()
# Out:
#                                          Image Index        labels  \
# 0  /content/xray_code/images/Cardiomegaly/0000000...  Cardiomegaly
# 1  /content/xray_code/images/No Finding/00000002_...    No Finding
# 2  /content/xray_code/images/Hernia/00000003_000.png        Hernia
# 3  /content/xray_code/images/Hernia/00000003_001.png        Hernia
# 4  /content/xray_code/images/Hernia/00000003_002.png        Hernia
#
#    Follow-up #  Patient ID  Patient Age Patient Gender View Position  \
# 0            0           1           58              M            PA
# 1            0           2           81              M            PA
# 2            0           3           81              F            PA
# 3            1           3           74              F            PA
# 4            2           3           75              F            PA
#
#    image_width  image_width.1  x_pixel_spacing  y_pixel_spacing
# 0         2682           2749            0.143            0.143
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-7c78238c071f> in <module>
# ----> 1 df = pd.read_csv("../sheets/normalized_xray_data_with_no_finding.csv")
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
# ...
